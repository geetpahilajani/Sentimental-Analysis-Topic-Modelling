# %% [markdown]
# ## Append the path of the module installed to sys ("use this when you get error Module not found even after installing package")

# %%
import sys
sys.path.append('/usr/local/lib64/python3.6/site-packages')
sys.path.append('/usr/local/lib/python3.6/site-packages')
sys.path.append('/usr/local/lib/python3.6/site-packages')
import pandas as pd

# %%
# !sudo python3 -m pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading https://files.pythonhosted.org/packages/ae/af/849edf14d573eba9c8082db898ff0d090428d9485371cc4fe21a66717ad2/wordcloud-1.5.0-cp36-cp36m-manylinux1_x86_64.whl (361kB)
#     100% |████████████████████████████████| 368kB 3.5MB/s eta 0:00:01
# Collecting pillow (from wordcloud)
#   Downloading https://files.pythonhosted.org/packages/14/41/db6dec65ddbc176a59b89485e8cc136a433ed9c6397b6bfe2cd38412051e/Pillow-6.1.0-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
#     100% |████████████████████████████████| 2.1MB 645kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib64/python3.6/site-packages (from wordcloud)
# Installing collected packages: pillow, wordcloud
# Successfully installed pillow-6.1.0 wordcloud-1.5.0
# You are using pip version 9.0.3, however version 19.2.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !conda install --user https://conda.anaconda.org/conda-forge wordcloud
# Out:
# usage: conda [-h] [-V] command ...
# conda: error: unrecognized arguments: --user

# %%
from w
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-51-ea768aabc966> in <module>()
# ----> 1 from wordcloud import wordcloud
#
# ImportError: No module named 'wordcloud'

# %%
# !sudo python3 -m pip uninstall Pillow
# !y
# Out:
# Uninstalling Pillow-6.1.0:
#   /usr/local/lib64/python3.6/site-packages/PIL/.libs/libfreetype-6d1da9cf.so.6.17.0
#   /usr/local/lib64/python3.6/site-packages/PIL/.libs/libjpeg-3b10b538.so.9.3.0
#   /usr/local/lib64/python3.6/site-packages/PIL/.libs/liblcms2-a6801db4.so.2.0.8
#   /usr/local/lib64/python3.6/site-packages/PIL/.libs/liblzma-6cd627ed.so.5.2.4
#   /usr/local/lib64/python3.6/site-packages/PIL/.libs/libopenjp2-b3d7668a.so.2.3.1
#   /usr/local/lib64/python3.6/site-packages/PIL/.libs/libpng16-bedcb7ea.so.16.37.0
#   /usr/local/lib64/python3.6/site-packages/PIL/.libs/libtiff-8267adfe.so.5.4.0
#   /usr/local/lib64/python3.6/site-packages/PIL/.libs/libwebp-baad113c.so.7.0.4
#   /usr/local/lib64/python3.6/site-packages/PIL/.libs/libwebpdemux-60cc0b6d.so.2.0.6
#   /usr/local/lib64/python3.6/site-packages/PIL/.libs/libwebpmux-75695800.so.3.0.4
#   /usr/local/lib64/python3.6/site-packages/PIL/.libs/libz-a147dcb0.so.1.2.3
#   /usr/local/lib64/python3.6/site-packages/PIL/BdfFontFile.py
#   /usr/local/lib64/python3.6/site-packages/PIL/BlpImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/BmpImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/BufrStubImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ContainerIO.py
#   /usr/local/lib64/python3.6/site-packages/PIL/CurImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/DcxImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/DdsImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/EpsImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ExifTags.py
#   /usr/local/lib64/python3.6/site-packages/PIL/FitsStubImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/FliImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/FontFile.py
#   /usr/local/lib64/python3.6/site-packages/PIL/FpxImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/FtexImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/GbrImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/GdImageFile.py
#   /usr/local/lib64/python3.6/site-packages/PIL/GifImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/GimpGradientFile.py
#   /usr/local/lib64/python3.6/site-packages/PIL/GimpPaletteFile.py
#   /usr/local/lib64/python3.6/site-packages/PIL/GribStubImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/Hdf5StubImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/IcnsImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/IcoImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/Image.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageChops.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageCms.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageColor.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageDraw.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageDraw2.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageEnhance.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageFile.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageFilter.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageFont.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageGrab.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageMath.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageMode.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageMorph.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageOps.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImagePalette.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImagePath.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageQt.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageSequence.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageShow.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageStat.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageTk.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageTransform.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImageWin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/ImtImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/IptcImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/Jpeg2KImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/JpegImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/JpegPresets.py
#   /usr/local/lib64/python3.6/site-packages/PIL/McIdasImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/MicImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/MpegImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/MpoImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/MspImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/PSDraw.py
#   /usr/local/lib64/python3.6/site-packages/PIL/PaletteFile.py
#   /usr/local/lib64/python3.6/site-packages/PIL/PalmImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/PcdImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/PcfFontFile.py
#   /usr/local/lib64/python3.6/site-packages/PIL/PcxImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/PdfImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/PdfParser.py
#   /usr/local/lib64/python3.6/site-packages/PIL/PixarImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/PngImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/PpmImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/PsdImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/PyAccess.py
#   /usr/local/lib64/python3.6/site-packages/PIL/SgiImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/SpiderImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/SunImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/TarIO.py
#   /usr/local/lib64/python3.6/site-packages/PIL/TgaImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/TiffImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/TiffTags.py
#   /usr/local/lib64/python3.6/site-packages/PIL/WalImageFile.py
#   /usr/local/lib64/python3.6/site-packages/PIL/WebPImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/WmfImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/XVThumbImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/XbmImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/XpmImagePlugin.py
#   /usr/local/lib64/python3.6/site-packages/PIL/__init__.py
#   /usr/local/lib64/python3.6/site-packages/PIL/__main__.py
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/BdfFontFile.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/BlpImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/BmpImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/BufrStubImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ContainerIO.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/CurImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/DcxImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/DdsImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/EpsImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ExifTags.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/FitsStubImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/FliImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/FontFile.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/FpxImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/FtexImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/GbrImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/GdImageFile.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/GifImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/GimpGradientFile.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/GimpPaletteFile.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/GribStubImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/Hdf5StubImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/IcnsImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/IcoImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/Image.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageChops.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageCms.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageColor.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageDraw.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageDraw2.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageEnhance.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageFile.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageFilter.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageFont.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageGrab.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageMath.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageMode.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageMorph.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageOps.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImagePalette.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImagePath.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageQt.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageSequence.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageShow.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageStat.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageTk.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageTransform.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImageWin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/ImtImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/IptcImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/Jpeg2KImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/JpegImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/JpegPresets.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/McIdasImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/MicImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/MpegImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/MpoImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/MspImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/PSDraw.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/PaletteFile.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/PalmImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/PcdImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/PcfFontFile.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/PcxImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/PdfImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/PdfParser.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/PixarImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/PngImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/PpmImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/PsdImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/PyAccess.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/SgiImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/SpiderImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/SunImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/TarIO.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/TgaImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/TiffImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/TiffTags.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/WalImageFile.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/WebPImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/WmfImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/XVThumbImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/XbmImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/XpmImagePlugin.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/__init__.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/__main__.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/_binary.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/_tkinter_finder.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/_util.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/_version.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/__pycache__/features.cpython-36.pyc
#   /usr/local/lib64/python3.6/site-packages/PIL/_binary.py
#   /usr/local/lib64/python3.6/site-packages/PIL/_imaging.cpython-36m-x86_64-linux-gnu.so
#   /usr/local/lib64/python3.6/site-packages/PIL/_imagingcms.cpython-36m-x86_64-linux-gnu.so
#   /usr/local/lib64/python3.6/site-packages/PIL/_imagingft.cpython-36m-x86_64-linux-gnu.so
#   /usr/local/lib64/python3.6/site-packages/PIL/_imagingmath.cpython-36m-x86_64-linux-gnu.so
#   /usr/local/lib64/python3.6/site-packages/PIL/_imagingmorph.cpython-36m-x86_64-linux-gnu.so
#   /usr/local/lib64/python3.6/site-packages/PIL/_imagingtk.cpython-36m-x86_64-linux-gnu.so
#   /usr/local/lib64/python3.6/site-packages/PIL/_tkinter_finder.py
#   /usr/local/lib64/python3.6/site-packages/PIL/_util.py
#   /usr/local/lib64/python3.6/site-packages/PIL/_version.py
#   /usr/local/lib64/python3.6/site-packages/PIL/_webp.cpython-36m-x86_64-linux-gnu.so
#   /usr/local/lib64/python3.6/site-packages/PIL/features.py
#   /usr/local/lib64/python3.6/site-packages/Pillow-6.1.0.dist-info/INSTALLER
#   /usr/local/lib64/python3.6/site-packages/Pillow-6.1.0.dist-info/METADATA
#   /usr/local/lib64/python3.6/site-packages/Pillow-6.1.0.dist-info/RECORD
#   /usr/local/lib64/python3.6/site-packages/Pillow-6.1.0.dist-info/WHEEL
#   /usr/local/lib64/python3.6/site-packages/Pillow-6.1.0.dist-info/top_level.txt
#   /usr/local/lib64/python3.6/site-packages/Pillow-6.1.0.dist-info/zip-safe
# Proceed (y/n)? ^C
# Operation cancelled by user
# You are using pip version 9.0.3, however version 19.2.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# /bin/sh: y: command not found

# %%
# !python3 -m nltk.downloader stopwords

# %%
import nltk
nltk.download('stopwords')
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1045)>
# [nltk_data] Error loading punkt: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1045)>
# False

# %%
# !python3 -m pip install --user nltk

# %%
import sqlite3
import pandas as pd
import matplotlib
import urllib
#import lxml.html
#import urllib.parse
#from lxml.html import tostring, html5parser
import nltk
from nltk.tokenize import LineTokenizer
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier

# %%
Pd_song_read= pd.read_csv('billboard_lyrics_1964-2015.csv',sep=',',quotechar='"',encoding='latin-1')

# %%
Pd_song_read.info()

# %%
Pd_song_read['Lyrics'] = Pd_song_read['Lyrics'].astype('str')

# %% [markdown]
# ## removing extra characters from the lyrics

# %%
Pd_song_read['Lyrics'] = [x.strip('/') for x in Pd_song_read['Lyrics']]

# %% [markdown]
# ## dropping records having no lyrics

# %%
Pd_song_read = Pd_song_read[Pd_song_read['Lyrics']!='  ']

# %% [markdown]
# ## dropping songs doesnt have lyrics and replaced with nan

# %%
Pd_song_read = Pd_song_read[Pd_song_read['Lyrics'] != 'nan']

# %% [markdown]
# ## tokenizing the lyrics

# %%
def identify_tokens(row):
    Lyrics = row['Lyrics']
    tokens = nltk.tokenize.word_tokenize(Lyrics)
    # taken only words (not punctuation)
    token_words = [w for w in tokens if w.isalpha()]
    return token_words

#Pd_song_read['lr'] = Pd_song_read.apply(identify_tokens, axis=1)

# %%
Pd_song_read['lr'] = Pd_song_read.apply(identify_tokens, axis=1)

# %%
Pd_song_read
# Out:
#       Rank                                      Song  \
# 0        1                               wooly bully
# 1        2  i cant help myself sugar pie honey bunch
# 3        4                       you were on my mind
# 4        5              youve lost that lovin feelin
# 5        6                                  downtown
# 6        7                                      help
# 7        8               cant you hear my heart beat
# 8        9                      crying in the chapel
# 9       10                                   my girl
# 10      11                            help me rhonda
# 11      12                          king of the road
# 12      13                    the birds and the bees
# 13      14                 hold me thrill me kiss me
# 14      15                                   shotgun
# 15      16                            i got you babe
# 16      17                         this diamond ring
# 17      18                              the in crowd
# 18      19     mrs brown youve got a lovely daughter
# 19      20                  stop in the name of love
# 20      21                          unchained melody
# 21      22                               silhouettes
# 22      23                ill never find another you
# 23      24                                  cara mia
# 24      25                         mr tambourine man
# 25      26                cast your fate to the wind
# 26      27                              yes im ready
# 27      28                        whats new pussycat
# 28      29                        eve of destruction
# 29      30                            hang on sloopy
# 30      31                            ticket to ride
# ...    ...                                       ...
# 5069    70                                   no type
# 5070    71                                   riptide
# 5071    72                               classic man
# 5072    73                                  exs  ohs
# 5073    74                       dear future husband
# 5074    75                               marvin gaye
# 5075    76                    like im gonna lose you
# 5076    77                          habits stay high
# 5077    78                          the hanging tree
# 5078    79                                      coco
# 5079    80                                 bang bang
# 5080    81                               lay me down
# 5081    82                                   tuesday
# 5082    83                              hit the quan
# 5083    84                                  downtown
# 5084    85                               house party
# 5085    86                                       ayo
# 5086    87                          kick the dust up
# 5087    88                                 blessings
# 5088    89                                  budapest
# 5089    90                                chandelier
# 5090    91                            heartbeat song
# 5091    92                                      dont
# 5092    93                                     ghost
# 5093    94                                      here
# 5094    95                                     waves
# 5095    96                                 el perdon
# 5097    98                             night changes
# 5098    99                              back to back
# 5099   100                     how deep is your love
#
#                                                  Artist  Year  \
# 0                         sam the sham and the pharaohs  1965
# 1                                             four tops  1965
# 3                                               we five  1965
# 4                                the righteous brothers  1965
# 5                                          petula clark  1965
# 6                                           the beatles  1965
# 7                                       hermans hermits  1965
# 8                                         elvis presley  1965
# 9                                       the temptations  1965
# 10                                       the beach boys  1965
# 11                                         roger miller  1965
# 12                                          jewel akens  1965
# 13                                           mel carter  1965
# 14                         junior walker  the all stars  1965
# 15                                          sonny  cher  1965
# 16                             gary lewis  the playboys  1965
# 17                                    ramsey lewis trio  1965
# 18                                      hermans hermits  1965
# 19                                         the supremes  1965
# 20                               the righteous brothers  1965
# 21                                      hermans hermits  1965
# 22                                          the seekers  1965
# 23                                jay and the americans  1965
# 24                                            the byrds  1965
# 25                                    sounds orchestral  1965
# 26                                        barbara mason  1965
# 27                                            tom jones  1965
# 28                                        barry mcguire  1965
# 29                                           the mccoys  1965
# 30                                          the beatles  1965
# ...                                                 ...   ...
# 5069                                       rae sremmurd  2015
# 5070                                          vance joy  2015
# 5071                 jidenna featuring roman gianarthur  2015
# 5072                                          elle king  2015
# 5073                                     meghan trainor  2015
# 5074              charlie puth featuring meghan trainor  2015
# 5075               meghan trainor featuring john legend  2015
# 5076                                            tove lo  2015
# 5077    james newton howard featuring jennifer lawrence  2015
# 5078                                         ot genasis  2015
# 5079             jessie j ariana grande and nicki minaj  2015
# 5080                                          sam smith  2015
# 5081                      ilovemakonnen featuring drake  2015
# 5082                                       ilovememphis  2015
# 5083  macklemore and ryan lewis featuring eric nally...  2015
# 5084                                           sam hunt  2015
# 5085                               chris brown and tyga  2015
# 5086                                         luke bryan  2015
# 5087                           big sean featuring drake  2015
# 5088                                        george ezra  2015
# 5089                                                sia  2015
# 5090                                     kelly clarkson  2015
# 5091                                         ed sheeran  2015
# 5092                                     ella henderson  2015
# 5093                                       alessia cara  2015
# 5094                                           mr probz  2015
# 5095                     nicky jam and enrique iglesias  2015
# 5097                                      one direction  2015
# 5098                                              drake  2015
# 5099                        calvin harris and disciples  2015
#
#                                                  Lyrics  Source  \
# 0     sam the sham miscellaneous wooly bully wooly b...     3.0
# 1      sugar pie honey bunch you know that i love yo...     1.0
# 3      when i woke up this morning you were on my mi...     1.0
# 4      you never close your eyes anymore when i kiss...     1.0
# 5      when youre alone and life is making you lonel...     1.0
# 6     help i need somebody help not just anybody hel...     3.0
# 7     carterlewis every time i see you lookin my way...     5.0
# 8      you saw me crying in the chapel the tears i s...     1.0
# 9     ive got sunshine on a cloudy day when its cold...     3.0
# 10    well since she put me down i ve been out doin ...     3.0
# 11     trailer for sale or rent rooms to let fifty c...     1.0
# 12    let me tell ya bout the birds and the bees and...     3.0
# 13     hold me hold me never let me go until youve t...     1.0
# 14    i said Ì¢shotgun shoot em for he runs now do t...     3.0
# 15    they say were young and we dont know we wont f...     3.0
# 16    who wants to buy this diamond ring she took it...     3.0
# 17                                         instrumental     3.0
# 18     mrs brown youve got a lovely daughter girls a...     1.0
# 19     stop in the name of love before you break my ...     1.0
# 20     oh my love my darling ive hungered for your t...     1.0
# 21     slaycrewetook a walk and passed your house la...     1.0
# 22     theres a new world somewhere they call the pr...     1.0
# 23    mantovani cara mia why must we say goodbye eac...     3.0
# 24     hey mr tambourine man play a song for me im n...     1.0
# 25    a month of nights a year of days octobers drif...     3.0
# 26    are you ready yes im ready are you ready yes i...     5.0
# 27     whats new pussycat woah woah whats new pussyc...     1.0
# 28     the eastern world it is explodin violence fla...     1.0
# 29    hang on sloopy sloopy hang on hang on sloopy s...     3.0
# 30    i think im gonna be sad i think its today yeah...     3.0
# ...                                                 ...     ...
# 5069   yah bad bitches is the yahi aint got no type ...     1.0
# 5070   i was scared of dentists and the dark i was s...     1.0
# 5071   my name calling all night i could pull the wo...     1.0
# 5072  verse 1 well i had me a boy turned him into a ...     5.0
# 5073   dear future husband heres a few things youll ...     1.0
# 5074   lets marvin gaye and get it on you got the he...     1.0
# 5075   i found myself dreaming in silver and gold li...     1.0
# 5076   uhuh uhuh uhuh i eat my dinner in my bathtub ...     1.0
# 5077   are you are you coming to the tree they strun...     1.0
# 5078   im in love with the coco coco coco im in love...     1.0
# 5079  verse 1 jessie j she got a body like an hourgl...     3.0
# 5080   yes i do i believe that one day i will be whe...     1.0
# 5081  hook x4 club goin up on a tuesday got your gir...     3.0
# 5082   yo yo aye im finna aye im finnaim finna show ...     1.0
# 5083   i went to the moped store said fuck it salesm...     1.0
# 5084   youre on the couch blowing up my phone you do...     1.0
# 5085   i need you i need you i need you i need you i...     1.0
# 5086   all week long its a farmin town theyre makin ...     1.0
# 5087   look i feel blessed way up i feel blessed way...     1.0
# 5088   my house in budapest my hidden treasure chest...     1.0
# 5089   party girls dont get hurt cant feel anything ...     1.0
# 5090   this is my heartbeat song and im gonna play i...     1.0
# 5091   i met this girl late last year she said dont ...     1.0
# 5092   i keep going to the river to pray cause i nee...     1.0
# 5093   i guess right now youve got the last laughim ...     1.0
# 5094   my face above the water my feet cant touch th...     1.0
# 5095  enrique iglesias dime si es verdad me dijeron ...     3.0
# 5097   going out tonight changes into something red ...     1.0
# 5098   oh man oh man oh man not againyeah i learned ...     1.0
# 5099   i want you to breathe me in let me be your ai...     1.0
#
#                                                      lr
# 0     [sam, the, sham, miscellaneous, wooly, bully, ...
# 1     [sugar, pie, honey, bunch, you, know, that, i,...
# 3     [when, i, woke, up, this, morning, you, were, ...
# 4     [you, never, close, your, eyes, anymore, when,...
# 5     [when, youre, alone, and, life, is, making, yo...
# 6     [help, i, need, somebody, help, not, just, any...
# 7     [carterlewis, every, time, i, see, you, lookin...
# 8     [you, saw, me, crying, in, the, chapel, the, t...
# 9     [ive, got, sunshine, on, a, cloudy, day, when,...
# 10    [well, since, she, put, me, down, i, ve, been,...
# 11    [trailer, for, sale, or, rent, rooms, to, let,...
# 12    [let, me, tell, ya, bout, the, birds, and, the...
# 13    [hold, me, hold, me, never, let, me, go, until...
# 14    [i, said, shoot, em, for, he, runs, now, do, t...
# 15    [they, say, were, young, and, we, dont, know, ...
# 16    [who, wants, to, buy, this, diamond, ring, she...
# 17                                       [instrumental]
# 18    [mrs, brown, youve, got, a, lovely, daughter, ...
# 19    [stop, in, the, name, of, love, before, you, b...
# 20    [oh, my, love, my, darling, ive, hungered, for...
# 21    [slaycrewetook, a, walk, and, passed, your, ho...
# 22    [theres, a, new, world, somewhere, they, call,...
# 23    [mantovani, cara, mia, why, must, we, say, goo...
# 24    [hey, mr, tambourine, man, play, a, song, for,...
# 25    [a, month, of, nights, a, year, of, days, octo...
# 26    [are, you, ready, yes, im, ready, are, you, re...
# 27    [whats, new, pussycat, woah, woah, whats, new,...
# 28    [the, eastern, world, it, is, explodin, violen...
# 29    [hang, on, sloopy, sloopy, hang, on, hang, on,...
# 30    [i, think, im, gon, na, be, sad, i, think, its...
# ...                                                 ...
# 5069  [yah, bad, bitches, is, the, yahi, aint, got, ...
# 5070  [i, was, scared, of, dentists, and, the, dark,...
# 5071  [my, name, calling, all, night, i, could, pull...
# 5072  [verse, well, i, had, me, a, boy, turned, him,...
# 5073  [dear, future, husband, heres, a, few, things,...
# 5074  [lets, marvin, gaye, and, get, it, on, you, go...
# 5075  [i, found, myself, dreaming, in, silver, and, ...
# 5076  [uhuh, uhuh, uhuh, i, eat, my, dinner, in, my,...
# 5077  [are, you, are, you, coming, to, the, tree, th...
# 5078  [im, in, love, with, the, coco, coco, coco, im...
# 5079  [verse, jessie, j, she, got, a, body, like, an...
# 5080  [yes, i, do, i, believe, that, one, day, i, wi...
# 5081  [hook, club, goin, up, on, a, tuesday, got, yo...
# 5082  [yo, yo, aye, im, finna, aye, im, finnaim, fin...
# 5083  [i, went, to, the, moped, store, said, fuck, i...
# 5084  [youre, on, the, couch, blowing, up, my, phone...
# 5085  [i, need, you, i, need, you, i, need, you, i, ...
# 5086  [all, week, long, its, a, farmin, town, theyre...
# 5087  [look, i, feel, blessed, way, up, i, feel, ble...
# 5088  [my, house, in, budapest, my, hidden, treasure...
# 5089  [party, girls, dont, get, hurt, cant, feel, an...
# 5090  [this, is, my, heartbeat, song, and, im, gon, ...
# 5091  [i, met, this, girl, late, last, year, she, sa...
# 5092  [i, keep, going, to, the, river, to, pray, cau...
# 5093  [i, guess, right, now, youve, got, the, last, ...
# 5094  [my, face, above, the, water, my, feet, cant, ...
# 5095  [enrique, iglesias, dime, si, es, verdad, me, ...
# 5097  [going, out, tonight, changes, into, something...
# 5098  [oh, man, oh, man, oh, man, not, againyeah, i,...
# 5099  [i, want, you, to, breathe, me, in, let, me, b...
#
# [4868 rows x 7 columns]

# %% [markdown]
# ## Removing Stop Words

# %%
stops = set(nltk.corpus.stopwords.words("english"))
t = ('ive','youre','verse','im','yo','oh','yea','ah','sham',
     'sam','mrs','yea','sloopy','hey','mr','woah','aint','yah'
    ,'uhuh','im', 'dont', 'know','just', 'got', 'yeah','make',
     'let','come','wanna','ill','aint','tell','ya','get', 'go', 
     'see', 'one', 'take', 'la','ooh','id','youll','na','theyll','ever','theres','youve')
stops.update(t)


def remove_stops(row):
    my_list = row['lr']
    meaningful_words = [w for w in my_list if not w in stops]
    return (meaningful_words)

Pd_song_read['stopword_lyrc'] = Pd_song_read.apply(remove_stops, axis=1)

# %% [markdown]
# stops

# %%
Pd_song_read
# Out:
#       Rank                                      Song  \
# 0        1                               wooly bully
# 1        2  i cant help myself sugar pie honey bunch
# 3        4                       you were on my mind
# 4        5              youve lost that lovin feelin
# 5        6                                  downtown
# 6        7                                      help
# 7        8               cant you hear my heart beat
# 8        9                      crying in the chapel
# 9       10                                   my girl
# 10      11                            help me rhonda
# 11      12                          king of the road
# 12      13                    the birds and the bees
# 13      14                 hold me thrill me kiss me
# 14      15                                   shotgun
# 15      16                            i got you babe
# 16      17                         this diamond ring
# 17      18                              the in crowd
# 18      19     mrs brown youve got a lovely daughter
# 19      20                  stop in the name of love
# 20      21                          unchained melody
# 21      22                               silhouettes
# 22      23                ill never find another you
# 23      24                                  cara mia
# 24      25                         mr tambourine man
# 25      26                cast your fate to the wind
# 26      27                              yes im ready
# 27      28                        whats new pussycat
# 28      29                        eve of destruction
# 29      30                            hang on sloopy
# 30      31                            ticket to ride
# ...    ...                                       ...
# 5069    70                                   no type
# 5070    71                                   riptide
# 5071    72                               classic man
# 5072    73                                  exs  ohs
# 5073    74                       dear future husband
# 5074    75                               marvin gaye
# 5075    76                    like im gonna lose you
# 5076    77                          habits stay high
# 5077    78                          the hanging tree
# 5078    79                                      coco
# 5079    80                                 bang bang
# 5080    81                               lay me down
# 5081    82                                   tuesday
# 5082    83                              hit the quan
# 5083    84                                  downtown
# 5084    85                               house party
# 5085    86                                       ayo
# 5086    87                          kick the dust up
# 5087    88                                 blessings
# 5088    89                                  budapest
# 5089    90                                chandelier
# 5090    91                            heartbeat song
# 5091    92                                      dont
# 5092    93                                     ghost
# 5093    94                                      here
# 5094    95                                     waves
# 5095    96                                 el perdon
# 5097    98                             night changes
# 5098    99                              back to back
# 5099   100                     how deep is your love
#
#                                                  Artist  Year  \
# 0                         sam the sham and the pharaohs  1965
# 1                                             four tops  1965
# 3                                               we five  1965
# 4                                the righteous brothers  1965
# 5                                          petula clark  1965
# 6                                           the beatles  1965
# 7                                       hermans hermits  1965
# 8                                         elvis presley  1965
# 9                                       the temptations  1965
# 10                                       the beach boys  1965
# 11                                         roger miller  1965
# 12                                          jewel akens  1965
# 13                                           mel carter  1965
# 14                         junior walker  the all stars  1965
# 15                                          sonny  cher  1965
# 16                             gary lewis  the playboys  1965
# 17                                    ramsey lewis trio  1965
# 18                                      hermans hermits  1965
# 19                                         the supremes  1965
# 20                               the righteous brothers  1965
# 21                                      hermans hermits  1965
# 22                                          the seekers  1965
# 23                                jay and the americans  1965
# 24                                            the byrds  1965
# 25                                    sounds orchestral  1965
# 26                                        barbara mason  1965
# 27                                            tom jones  1965
# 28                                        barry mcguire  1965
# 29                                           the mccoys  1965
# 30                                          the beatles  1965
# ...                                                 ...   ...
# 5069                                       rae sremmurd  2015
# 5070                                          vance joy  2015
# 5071                 jidenna featuring roman gianarthur  2015
# 5072                                          elle king  2015
# 5073                                     meghan trainor  2015
# 5074              charlie puth featuring meghan trainor  2015
# 5075               meghan trainor featuring john legend  2015
# 5076                                            tove lo  2015
# 5077    james newton howard featuring jennifer lawrence  2015
# 5078                                         ot genasis  2015
# 5079             jessie j ariana grande and nicki minaj  2015
# 5080                                          sam smith  2015
# 5081                      ilovemakonnen featuring drake  2015
# 5082                                       ilovememphis  2015
# 5083  macklemore and ryan lewis featuring eric nally...  2015
# 5084                                           sam hunt  2015
# 5085                               chris brown and tyga  2015
# 5086                                         luke bryan  2015
# 5087                           big sean featuring drake  2015
# 5088                                        george ezra  2015
# 5089                                                sia  2015
# 5090                                     kelly clarkson  2015
# 5091                                         ed sheeran  2015
# 5092                                     ella henderson  2015
# 5093                                       alessia cara  2015
# 5094                                           mr probz  2015
# 5095                     nicky jam and enrique iglesias  2015
# 5097                                      one direction  2015
# 5098                                              drake  2015
# 5099                        calvin harris and disciples  2015
#
#                                                  Lyrics  Source  \
# 0     sam the sham miscellaneous wooly bully wooly b...     3.0
# 1      sugar pie honey bunch you know that i love yo...     1.0
# 3      when i woke up this morning you were on my mi...     1.0
# 4      you never close your eyes anymore when i kiss...     1.0
# 5      when youre alone and life is making you lonel...     1.0
# 6     help i need somebody help not just anybody hel...     3.0
# 7     carterlewis every time i see you lookin my way...     5.0
# 8      you saw me crying in the chapel the tears i s...     1.0
# 9     ive got sunshine on a cloudy day when its cold...     3.0
# 10    well since she put me down i ve been out doin ...     3.0
# 11     trailer for sale or rent rooms to let fifty c...     1.0
# 12    let me tell ya bout the birds and the bees and...     3.0
# 13     hold me hold me never let me go until youve t...     1.0
# 14    i said Ì¢shotgun shoot em for he runs now do t...     3.0
# 15    they say were young and we dont know we wont f...     3.0
# 16    who wants to buy this diamond ring she took it...     3.0
# 17                                         instrumental     3.0
# 18     mrs brown youve got a lovely daughter girls a...     1.0
# 19     stop in the name of love before you break my ...     1.0
# 20     oh my love my darling ive hungered for your t...     1.0
# 21     slaycrewetook a walk and passed your house la...     1.0
# 22     theres a new world somewhere they call the pr...     1.0
# 23    mantovani cara mia why must we say goodbye eac...     3.0
# 24     hey mr tambourine man play a song for me im n...     1.0
# 25    a month of nights a year of days octobers drif...     3.0
# 26    are you ready yes im ready are you ready yes i...     5.0
# 27     whats new pussycat woah woah whats new pussyc...     1.0
# 28     the eastern world it is explodin violence fla...     1.0
# 29    hang on sloopy sloopy hang on hang on sloopy s...     3.0
# 30    i think im gonna be sad i think its today yeah...     3.0
# ...                                                 ...     ...
# 5069   yah bad bitches is the yahi aint got no type ...     1.0
# 5070   i was scared of dentists and the dark i was s...     1.0
# 5071   my name calling all night i could pull the wo...     1.0
# 5072  verse 1 well i had me a boy turned him into a ...     5.0
# 5073   dear future husband heres a few things youll ...     1.0
# 5074   lets marvin gaye and get it on you got the he...     1.0
# 5075   i found myself dreaming in silver and gold li...     1.0
# 5076   uhuh uhuh uhuh i eat my dinner in my bathtub ...     1.0
# 5077   are you are you coming to the tree they strun...     1.0
# 5078   im in love with the coco coco coco im in love...     1.0
# 5079  verse 1 jessie j she got a body like an hourgl...     3.0
# 5080   yes i do i believe that one day i will be whe...     1.0
# 5081  hook x4 club goin up on a tuesday got your gir...     3.0
# 5082   yo yo aye im finna aye im finnaim finna show ...     1.0
# 5083   i went to the moped store said fuck it salesm...     1.0
# 5084   youre on the couch blowing up my phone you do...     1.0
# 5085   i need you i need you i need you i need you i...     1.0
# 5086   all week long its a farmin town theyre makin ...     1.0
# 5087   look i feel blessed way up i feel blessed way...     1.0
# 5088   my house in budapest my hidden treasure chest...     1.0
# 5089   party girls dont get hurt cant feel anything ...     1.0
# 5090   this is my heartbeat song and im gonna play i...     1.0
# 5091   i met this girl late last year she said dont ...     1.0
# 5092   i keep going to the river to pray cause i nee...     1.0
# 5093   i guess right now youve got the last laughim ...     1.0
# 5094   my face above the water my feet cant touch th...     1.0
# 5095  enrique iglesias dime si es verdad me dijeron ...     3.0
# 5097   going out tonight changes into something red ...     1.0
# 5098   oh man oh man oh man not againyeah i learned ...     1.0
# 5099   i want you to breathe me in let me be your ai...     1.0
#
#                                                      lr  \
# 0     [sam, the, sham, miscellaneous, wooly, bully, ...
# 1     [sugar, pie, honey, bunch, you, know, that, i,...
# 3     [when, i, woke, up, this, morning, you, were, ...
# 4     [you, never, close, your, eyes, anymore, when,...
# 5     [when, youre, alone, and, life, is, making, yo...
# 6     [help, i, need, somebody, help, not, just, any...
# 7     [carterlewis, every, time, i, see, you, lookin...
# 8     [you, saw, me, crying, in, the, chapel, the, t...
# 9     [ive, got, sunshine, on, a, cloudy, day, when,...
# 10    [well, since, she, put, me, down, i, ve, been,...
# 11    [trailer, for, sale, or, rent, rooms, to, let,...
# 12    [let, me, tell, ya, bout, the, birds, and, the...
# 13    [hold, me, hold, me, never, let, me, go, until...
# 14    [i, said, shoot, em, for, he, runs, now, do, t...
# 15    [they, say, were, young, and, we, dont, know, ...
# 16    [who, wants, to, buy, this, diamond, ring, she...
# 17                                       [instrumental]
# 18    [mrs, brown, youve, got, a, lovely, daughter, ...
# 19    [stop, in, the, name, of, love, before, you, b...
# 20    [oh, my, love, my, darling, ive, hungered, for...
# 21    [slaycrewetook, a, walk, and, passed, your, ho...
# 22    [theres, a, new, world, somewhere, they, call,...
# 23    [mantovani, cara, mia, why, must, we, say, goo...
# 24    [hey, mr, tambourine, man, play, a, song, for,...
# 25    [a, month, of, nights, a, year, of, days, octo...
# 26    [are, you, ready, yes, im, ready, are, you, re...
# 27    [whats, new, pussycat, woah, woah, whats, new,...
# 28    [the, eastern, world, it, is, explodin, violen...
# 29    [hang, on, sloopy, sloopy, hang, on, hang, on,...
# 30    [i, think, im, gon, na, be, sad, i, think, its...
# ...                                                 ...
# 5069  [yah, bad, bitches, is, the, yahi, aint, got, ...
# 5070  [i, was, scared, of, dentists, and, the, dark,...
# 5071  [my, name, calling, all, night, i, could, pull...
# 5072  [verse, well, i, had, me, a, boy, turned, him,...
# 5073  [dear, future, husband, heres, a, few, things,...
# 5074  [lets, marvin, gaye, and, get, it, on, you, go...
# 5075  [i, found, myself, dreaming, in, silver, and, ...
# 5076  [uhuh, uhuh, uhuh, i, eat, my, dinner, in, my,...
# 5077  [are, you, are, you, coming, to, the, tree, th...
# 5078  [im, in, love, with, the, coco, coco, coco, im...
# 5079  [verse, jessie, j, she, got, a, body, like, an...
# 5080  [yes, i, do, i, believe, that, one, day, i, wi...
# 5081  [hook, club, goin, up, on, a, tuesday, got, yo...
# 5082  [yo, yo, aye, im, finna, aye, im, finnaim, fin...
# 5083  [i, went, to, the, moped, store, said, fuck, i...
# 5084  [youre, on, the, couch, blowing, up, my, phone...
# 5085  [i, need, you, i, need, you, i, need, you, i, ...
# 5086  [all, week, long, its, a, farmin, town, theyre...
# 5087  [look, i, feel, blessed, way, up, i, feel, ble...
# 5088  [my, house, in, budapest, my, hidden, treasure...
# 5089  [party, girls, dont, get, hurt, cant, feel, an...
# 5090  [this, is, my, heartbeat, song, and, im, gon, ...
# 5091  [i, met, this, girl, late, last, year, she, sa...
# 5092  [i, keep, going, to, the, river, to, pray, cau...
# 5093  [i, guess, right, now, youve, got, the, last, ...
# 5094  [my, face, above, the, water, my, feet, cant, ...
# 5095  [enrique, iglesias, dime, si, es, verdad, me, ...
# 5097  [going, out, tonight, changes, into, something...
# 5098  [oh, man, oh, man, oh, man, not, againyeah, i,...
# 5099  [i, want, you, to, breathe, me, in, let, me, b...
#
#                                           stopword_lyrc
# 0     [miscellaneous, wooly, bully, wooly, bully, ph...
# 1     [sugar, pie, honey, bunch, know, love, cant, h...
# 3     [woke, morning, mind, mind, got, troubles, who...
# 4     [never, close, eyes, anymore, kiss, lips, ther...
# 5     [alone, life, making, lonely, always, go, down...
# 6     [help, need, somebody, help, anybody, help, kn...
# 7     [carterlewis, every, time, see, lookin, way, b...
# 8     [saw, crying, chapel, tears, shed, tears, joy,...
# 9     [got, sunshine, cloudy, day, cold, outside, go...
# 10    [well, since, put, doin, head, come, late, nig...
# 11    [trailer, sale, rent, rooms, let, fifty, cents...
# 12    [let, tell, ya, bout, birds, bees, flowers, tr...
# 13    [hold, hold, never, let, go, youve, told, told...
# 14    [said, shoot, em, runs, jerk, baby, jerk, put,...
# 15    [say, young, dont, know, wont, find, grow, wel...
# 16    [wants, buy, diamond, ring, took, finger, does...
# 17                                       [instrumental]
# 18    [brown, youve, got, lovely, daughter, girls, s...
# 19    [stop, name, love, break, heartbaby, baby, awa...
# 20    [love, darling, hungered, touch, long, lonely,...
# 21    [slaycrewetook, walk, passed, house, late, las...
# 22    [theres, new, world, somewhere, call, promised...
# 23    [mantovani, cara, mia, must, say, goodbye, tim...
# 24    [tambourine, man, play, song, sleepy, place, g...
# 25    [month, nights, year, days, octobers, drifting...
# 26    [ready, yes, ready, ready, yes, ready, dont, e...
# 27    [whats, new, pussycat, whats, new, pussycat, w...
# 28    [eastern, world, explodin, violence, flarin, b...
# 29    [hang, hang, hang, hang, lives, bad, part, tow...
# 30    [think, gon, na, sad, think, today, yeah, girl...
# ...                                                 ...
# 5069  [bad, bitches, yahi, got, type, nah, bad, bitc...
# 5070  [scared, dentists, dark, scared, pretty, girls...
# 5071  [name, calling, night, could, pull, wool, poli...
# 5072  [well, boy, turned, man, showed, things, didnt...
# 5073  [dear, future, husband, heres, things, youll, ...
# 5074  [lets, marvin, gaye, get, got, healing, want, ...
# 5075  [found, dreaming, silver, gold, like, scene, m...
# 5076  [eat, dinner, bathtub, go, sex, clubs, watchin...
# 5077  [coming, tree, strung, man, say, murdered, thr...
# 5078  [love, coco, coco, coco, love, coco, coco, coc...
# 5079  [jessie, j, got, body, like, hourglass, give, ...
# 5080  [yes, believe, one, day, right, right, next, h...
# 5081  [hook, club, goin, tuesday, got, girl, cut, ch...
# 5082  [aye, finna, aye, finnaim, finna, show, hit, q...
# 5083  [went, moped, store, said, fuck, salesmans, li...
# 5084  [couch, blowing, phone, dont, want, come, dont...
# 5085  [need, need, need, need, need, need, need, nee...
# 5086  [week, long, farmin, town, theyre, makin, mone...
# 5087  [look, feel, blessed, way, feel, blessed, way,...
# 5088  [house, budapest, hidden, treasure, chest, gol...
# 5089  [party, girls, dont, get, hurt, cant, feel, an...
# 5090  [heartbeat, song, gon, na, play, long, forgot,...
# 5091  [met, girl, late, last, year, said, dont, worr...
# 5092  [keep, going, river, pray, cause, need, someth...
# 5093  [guess, right, youve, got, last, laughim, sorr...
# 5094  [face, water, feet, cant, touch, ground, touch...
# 5095  [enrique, iglesias, dime, si, es, verdad, dije...
# 5097  [going, tonight, changes, something, red, moth...
# 5098  [man, man, man, againyeah, learned, game, will...
# 5099  [want, breathe, let, air, let, roam, body, fre...
#
# [4868 rows x 8 columns]

# %% [markdown]
# ## function for finding length of songs

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (8,6)

df = pd.DataFrame(columns=('artist', 'words'))
i=0
for artist in Pd_song_read.Artist:
    f = Pd_song_read.stopword_lyrc
    num_words = 0
    all_text = ''
    for sentence in f:
        #this_sentence = sentence.decode('utf-8')
        num_words_this = len(sentence)
        #print(len(sentence))
        num_words += num_words_this

# %%
num_words
# Out:
# 827673

# %% [markdown]
# ## Removing stopwords from the Lyrics

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (8,6)

df = pd.DataFrame(columns=('artist', 'words'))
i=0
for artist in Pd_song_read.Artist:
    f = Pd_song_read.stopword_lyrc
    num_words = []
    all_text = ''
    for sentence in f:
        this_sentence = sentence
        num_words_this = len(this_sentence)
        num_words.append(num_words_this) 
     
    df.loc[i] = (artist)
    i+=1

# %%
df['words'] = num_words

# %% [markdown]
# ## Statistic showing number of words used by each artist in the songs

# %%
plt.style.use(['fast'])
df.head(20).plot.bar(x='artist',y='words',style='seaborn-talk')
plt.show()

# %%
#adding list to dataframe as column

# %%
plt.rcParams['figure.figsize'] = (50,60)

# %%
df['Rank'] = Pd_song_read['Rank']

# %%
df['Year'] = (Pd_song_read['Year'])

# %%
#Joining all the lyrics of songs without stop words

# %%
#long_string = ','.join(list(Pd_song_read['Lyrics'].values))

# %%
long_string = ''.join(list(str(Pd_song_read['stopword_lyrc'].values)))

# %%
#Word Cloud library to create cloud of words

# %%
# !python3 -m pip install --user wordcloud
# Out:
# Requirement already satisfied: wordcloud in /home/hadoop/.local/lib/python3.6/site-packages
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib64/python3.6/site-packages (from wordcloud)
# Requirement already satisfied: pillow in /home/hadoop/.local/lib/python3.6/site-packages (from wordcloud)
# You are using pip version 9.0.3, however version 19.2.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !python3 --version
# Out:
# Python 3.6.8

# %%
import wordcloud
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-77-dc1828f2a80e> in <module>()
# ----> 1 import wordcloud
#
# /usr/local/lib64/python3.6/site-packages/wordcloud/__init__.py in <module>()
# ----> 1 from .wordcloud import (WordCloud, STOPWORDS, random_color_func,
#       2                         get_single_color_func)
#       3 from .color_from_image import ImageColorGenerator
#       4
#       5 __all__ = ['WordCloud', 'STOPWORDS', 'random_color_func',
#
# /usr/local/lib64/python3.6/site-packages/wordcloud/wordcloud.py in <module>()
#      17 from operator import itemgetter
#      18
# ---> 19 from PIL import Image
#      20 from PIL import ImageColor
#      21 from PIL import ImageDraw
#
# /usr/local/lib64/python3.6/site-packages/PIL/Image.py in <module>()
#      93     # Also note that Image.core is not a publicly documented interface,
#      94     # and should be considered private and subject to change.
# ---> 95     from . import _imaging as core
#      96
#      97     if __version__ != getattr(core, "PILLOW_VERSION", None):
#
# ImportError: cannot import name '_imaging'

# %%
# !python3 -m pip install --user wordcloud
# !python3 -m pip install --user seaborn
# Out:
# Collecting wordcloud
#   Downloading https://files.pythonhosted.org/packages/c7/07/e43a7094a58e602e85a09494d9b99e7b5d71ca4789852287386e21e74c33/wordcloud-1.5.0-cp37-cp37m-macosx_10_6_x86_64.whl (157kB)
#      |████████████████████████████████| 163kB 1.7MB/s eta 0:00:01
# Requirement already satisfied: pillow in /Users/gpahilajani/anaconda3/envs/Python-3.7.3-Env/lib/python3.7/site-packages (from wordcloud) (6.1.0)
# Requirement already satisfied: numpy>=1.6.1 in /Users/gpahilajani/anaconda3/envs/Python-3.7.3-Env/lib/python3.7/site-packages (from wordcloud) (1.16.4)
# Installing collected packages: wordcloud
#   WARNING: The script wordcloud_cli is installed in '/Users/gpahilajani/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed wordcloud-1.5.0

# %%
wordcloud = wordcloud.(background_color="white", max_words=2000, contour_width=5, contour_color='steelblue',width=600,height=800)
# Out:
#   File "<ipython-input-55-f0c6b8b89a22>", line 1
#     wordcloud = wordcloud.(background_color="white", max_words=2000, contour_width=5, contour_color='steelblue',width=600,height=800)
#                           ^
# SyntaxError: invalid syntax

# %%
import wordcloud
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-40-dc1828f2a80e> in <module>()
# ----> 1 import wordcloud
#
# ImportError: No module named 'wordcloud'

# %%
# Generate a word cloud
wordcloud.generate(long_string)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-14-6ebbd1bc74a4> in <module>()
#       1
#       2 # Generate a word cloud
# ----> 3 wordcloud.generate(long_string)
#
# AttributeError: 'module' object has no attribute 'generate'

# %%
# Visualize the word cloud
wordcloud.to_image()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-12-de341f7fdc22> in <module>()
#       1 # Visualize the word cloud
# ----> 2 wordcloud.to_image()
#
# AttributeError: 'module' object has no attribute 'to_image'

# %%
# Load the library with the CountVectorizer method
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
#function to display top 30 comman words used in lyrics

# %%
def plot_10_most_common_words(count_data, count_vectorizer):
    import matplotlib.pyplot as plt
    words = count_vectorizer.get_feature_names()
    total_counts = np.zeros(len(words))
    for t in count_data:
        total_counts+=t.toarray()[0]
    
    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:50]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words)) 
    
    plt.figure(2, figsize=(15, 15/1.6180))
    plt.subplot(title='20 most common words')
    sns.set_context("notebook", font_scale=1.25, rc={"lines.linewidth": 2.5})
    sns.barplot(x_pos, counts, palette='husl')
    plt.xticks(x_pos, words, rotation=90) 
    plt.xlabel('words')
    plt.ylabel('counts')
    plt.show()

# %%
Pd_song_read.head(3)
# Out:
#    Rank                                      Song  \
# 0     1                               wooly bully
# 1     2  i cant help myself sugar pie honey bunch
# 3     4                       you were on my mind
#
#                           Artist  Year  \
# 0  sam the sham and the pharaohs  1965
# 1                      four tops  1965
# 3                        we five  1965
#
#                                               Lyrics  Source  \
# 0  sam the sham miscellaneous wooly bully wooly b...     3.0
# 1   sugar pie honey bunch you know that i love yo...     1.0
# 3   when i woke up this morning you were on my mi...     1.0
#
#                                                   lr  \
# 0  [sam, the, sham, miscellaneous, wooly, bully, ...
# 1  [sugar, pie, honey, bunch, you, know, that, i,...
# 3  [when, i, woke, up, this, morning, you, were, ...
#
#                                        stopword_lyrc
# 0  [miscellaneous, wooly, bully, wooly, bully, ph...
# 1  [sugar, pie, honey, bunch, love, cant, help, l...
# 3  [woke, morning, mind, mind, troubles, whoaoh, ...

# %%
count_vectorizer = CountVectorizer(stop_words=stops)

# %%
Pd_song_read['Year'].unique()
# Out:
# array([1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975,
#        1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
#        1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#        1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012, 2013, 2014, 2015])

# %%
df_65_70= Pd_song_read[Pd_song_read['Year'].isin([1965,1966,1967,1968,1969,1970])]
df_71_75 = Pd_song_read[Pd_song_read['Year'].isin([1971,1972,1973,1974,1975])]
df_1967 =  Pd_song_read[Pd_song_read['Year']==1967]
df_1968 = Pd_song_read[Pd_song_read['Year']==1968]

# %%
count_65_70 = count_vectorizer.fit_transform(df_65_70['Lyrics'])

# %%
count_71_75 = count_vectorizer.fit_transform(df_71_75['Lyrics'])

# %%
plot_10_most_common_words(count_65_70, count_vectorizer)

# %%
# Visualise the 10 most common words
plot_10_most_common_words(count_71_75, count_vectorizer)

# %%
'ya','get', 'go', 'see', 'one', 'take', 'la','ooh','id','youll','na','theyll','ever','theres','youve'

'us','oo','us','hes','thats','mia','shes','yes'

# %%
print(plt.style.available)

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('vader_lexicon')

# %%
Pd_song_read.stopword_lyrc.iloc[0]

# %%
Pd_song_read[Pd_song_read['Artist']=='the beach boys']

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

sentences=['sugar',
 'pie',
 'honey',
 'bunch',
 'know',
 'love',
 'cant',
 'help',
 'love',
 'nobody',
 'elsein',
 'life',
 'come',
 'go',
 'leaving',
 'picture',
 'behind',
 'kissed',
 'thousand',
 'timeswhen',
 'snap',
 'finger',
 'wink',
 'eye',
 'come',
 'arunning',
 'im',
 'tied',
 'apron',
 'strings',
 'theres',
 'nothing',
 'docant',
 'help',
 'cant',
 'help',
 'myselfsugar',
 'pie',
 'honey',
 'bunch',
 'im',
 'weaker',
 'man',
 'cant',
 'help',
 'im',
 'fool',
 'love',
 'seewanna',
 'tell',
 'dont',
 'love',
 'tell',
 'ive',
 'tried',
 'every',
 'time',
 'see',
 'face',
 'get',
 'choked',
 'insidewhen',
 'call',
 'name',
 'girl',
 'starts',
 'flame',
 'burning',
 'heart',
 'tearing',
 'apart',
 'matter',
 'try',
 'love',
 'hidecause',
 'sugar',
 'pie',
 'honey',
 'bunch',
 'know',
 'im',
 'weak',
 'cant',
 'help',
 'love',
 'nobody',
 'elsesugar',
 'pie',
 'honey',
 'bunch',
 'anything',
 'ask',
 'cant',
 'help',
 'want',
 'nobody',
 'elsesugar',
 'pie',
 'honey',
 'bunch',
 'know',
 'love',
 'cant',
 'help',
 'cant',
 'help']
for sentence in sentences:
    ss = sid.polarity_scores(sentence) 
print (ss)
# Out:
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4019}

# %%
#Using nltk check how much percentage of the lyrics of song is positive, negative and neutral

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
df = pd.DataFrame(columns=('artist', 'pos', 'neu', 'neg'))
sid = SentimentIntensityAnalyzer()
i=0
for artist in artists:
    num_positive = 0
    num_negative = 0
    num_neutral = 0

    f = open('lyrics/' + artist + '-cleaned', 'rb')
    for sentence in f.readlines():
        this_sentence = sentence.decode('utf-8')
        comp = sid.polarity_scores(this_sentence)
        comp = comp['compound']
        if comp >= 0.5:
            num_positive += 1
        elif comp > -0.5 and comp < 0.5:
            num_neutral += 1
        else:
            num_negative += 1

    num_total = num_negative + num_neutral + num_positive
    percent_negative = (num_negative/float(num_total))*100
    percent_neutral = (num_neutral/float(num_total))*100
    percent_positive = (num_positive/float(num_total))*100
    df.loc[i] = (artist, percent_positive, percent_neutral, percent_negative)
    i+=1
                 
df.plot.bar(x='artist', stacked=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-8489651c6213> in <module>
#       1 from nltk.sentiment.vader import SentimentIntensityAnalyzer
# ----> 2 df = pd.DataFrame(columns=('artist', 'pos', 'neu', 'neg'))
#       3 sid = SentimentIntensityAnalyzer()
#       4 i=0
#       5 for artist in artists:
#
# NameError: name 'pd' is not defined

# %%
comp.keys()

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
pdf_Label = pd.DataFrame(columns=('artist', 'pos', 'neu', 'neg'))
sid = SentimentIntensityAnalyzer()
i=0
num_positive = 0
num_negative = 0
num_neutral = 0
comp1 = []
for artist in Pd_song_read.Artist.head(500):
    f = Pd_song_read.Lyrics.head(500)
    for sentence in f:
        this_sentence = sentence
        #print(this_sentence)
        comp = sid.polarity_scores(this_sentence)
        comp1.append(comp)
    
      
    
    pdf_Label.loc[i] = (artist)
    i+=1
    
    
#pdf_Label.plot.bar(x='artist', stacked=True)
#plt.show()  
    
        
        #print(num_positive)
        #num_total = num_negative + num_neutral + num_positive
        #print(num_total)

# %%
# !pip install holoviews

# %%
#converting list to Pandas Dataframe

# %%
NEW = pd.DataFrame(comp1)

# %%
pdf_Label['neg'] = NEW['neg']
pdf_Label['pos'] = NEW['pos']
#pdf_Label['neu'] = NEW['neu']
#pdf_Label['compound'] = NEW['compound']

# %%
pdf_Label.count()

# %%
from bokeh.io import show, output_file
from bokeh.plotting import figure

# %%
bars = hv.Bars(pdf_Label)

# %%
pd.

# %%
pdf_Label.plot.bar(x='artist',stacked=True, figsize=(10,7))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(x=pdf_Label.artist,y=pdf_Label.neu)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-05aa696f8b1f> in <module>
# ----> 1 sns.barplot(x=pdf_Label.artist,y=pdf_Label.neu)
#
# NameError: name 'pdf_Label' is not defined

# %%
pdf_Label.plot.bar(x='artist', stacked=True,)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-dfe5bbafa665> in <module>
# ----> 1 pdf_Label.plot.bar(x='artist', stacked=True,)
#       2 plt.show()
#
# NameError: name 'pdf_Label' is not defined

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
pdf_Label = pd.DataFrame(columns=('artist', 'pos', 'neu', 'neg'))
sid = SentimentIntensityAnalyzer()
i=0
num_positive = 0
num_negative = 0
num_neutral = 0
for artist in Pd_song_read.Artist.head(50):
    f = Pd_song_read.Lyrics.head(50)
    for sentence in f:
        this_sentence = sentence
        #print(this_sentence)
        comp = sid.polarity_scores(this_sentence)
        
        comp1 = comp['compound']
        if comp1 >= 0.5:
            num_positive += 1
        elif comp1 > -0.5 and comp1 < 0.5:
            num_neutral += 1
        else:
            num_negative += 1
   
    print(artist,num_negative,num_neutral,num_positive)
    num_total = num_negative + num_neutral + num_positive
    print(num_total)
    percent_negative = (num_negative/(num_total))*100
    print(percent_negative)
    percent_neutral = (num_neutral/float(num_total))*100
    percent_positive = (num_positive/float(num_total))*100
    #print(artist,percent_negative,percent_negative,percent_positive)
    pdf_Label.loc[i] = (artist, num_positive, num_neutral, num_negative)
    i+=1
    
    
pdf_Label.plot.bar(x='artist', stacked=True)
plt.show()  
    
        
        #print(num_positive)
        #num_total = num_negative + num_neutral + num_positive
        #print(num_total)

# %%
(12/60)*100

# %%
pdf_Label

# %%
for artist in Pd_song_read.Artist.head(10):
    print(artist)

# %%
this_sentence

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
pdf_Label = pd.DataFrame(columns=('artist', 'pos', 'neu', 'neg'))
sid = SentimentIntensityAnalyzer()
i=0
for artist in Pd_song_read.Artist:
    num_positive = 0
    num_negative = 0
    num_neutral = 0
    
    f = Pd_song_read.Lyrics
    for sentence in f:
        this_sentence = sentence
        comp = sid.polarity_scores(this_sentence)
        comp = comp['compound']
        if comp >= 0.5:
            num_positive += 1
        elif comp > -0.5 and comp < 0.5:
            num_neutral += 1
        else:
            num_negative += 1
            
    num_total = num_negative + num_neutral + num_positive
    percent_negative = (num_negative/float(num_total))*100
    percent_neutral = (num_neutral/float(num_total))*100
    percent_positive = (num_positive/float(num_total))*100
    pdf_Label.loc[i] = (artist, percent_positive, percent_neutral, percent_negative)
    i+=1
    
pdf_Label.head(20).plot.bar(x='artist', stacked=True)
plt.show()

# %%
num_positive=[]
for i in range(2):
    num_positive =+1

# %%
num_positive

# %%
num_words_this

# %%
pdf_Label

# %%
num_words

# %%
for artist in artists:
    f = open('lyrics/' + artist + '-cleaned', 'rb')
    all_words = ''
    num_words = 0
    raw_text = ""
    for sentence in f.readlines():
        this_sentence = sentence.decode('utf-8')
        raw_text += this_sentence
            
    words = raw_text.split(" ")
    filtered_words = [word for word in words if word not in stopwords.words('english') and len(word) > 1 and word not in ['na','la']] # remove the stopwords
    
    a = len(set(filtered_words))
    b = len(words)
    df.loc[i] = (artist, (a/float(b))*100)
    i+=1

# %% [markdown]
# ## Reading dataset with Genre

# %%
Lyrics_Genre = pd.read_csv('lyrics 3.csv')

# %%
lyric_filtered = Lyrics_Genre.head(30000)

# %%
lyric_filtered.head(2)
# Out:
#    index          song  year           artist genre  \
# 0      0     ego-remix  2009  beyonce-knowles   Pop
# 1      1  then-tell-me  2009  beyonce-knowles   Pop
#
#                                               lyrics
# 0  Oh baby, how you doing?\nYou know I'm gonna cu...
# 1  playin' everything so easy,\nit's like you see...

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
# cleaning text

# %%
lyric_filtered['lyrics'] = [x.strip('.\n') for x in lyric_filtered['lyrics'].astype('str')]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
lyric_filtered.drop(columns=['index'],inplace=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %% [markdown]
# ## setting the lyrics in lower string format

# %%
lyric_filtered['llr'] = lyric_filtered['lyrics'].str.lower()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Replacing Extra Character

# %%
lyric_filtered['lyrics'] = lyric_filtered['lyrics'].str.replace('[^\w\s\n]','')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Replacing Digits

# %%
lyric_filtered['lyrics'] = lyric_filtered['lyrics'].str.replace('\d+','')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
lyric_filtered.head()
# Out:
#               song  year           artist genre  \
# 0        ego-remix  2009  beyonce-knowles   Pop
# 1     then-tell-me  2009  beyonce-knowles   Pop
# 2          honesty  2009  beyonce-knowles   Pop
# 3  you-are-my-rock  2009  beyonce-knowles   Pop
# 4    black-culture  2009  beyonce-knowles   Pop
#
#                                               lyrics  \
# 0  Oh baby, how you doing?\nYou know I'm gonna cu...
# 1  playin' everything so easy,\nit's like you see...
# 2  If you search\nFor tenderness\nIt isn't hard t...
# 3  Oh oh oh I, oh oh oh I\n[Verse 1:]\nIf I wrote...
# 4  Party the people, the people the party it's po...
#
#                                                  llr
# 0  oh baby, how you doing?\nyou know i'm gonna cu...
# 1  playin' everything so easy,\nit's like you see...
# 2  if you search\nfor tenderness\nit isn't hard t...
# 3  oh oh oh i, oh oh oh i\n[verse 1:]\nif i wrote...
# 4  party the people, the people the party it's po...

# %% [markdown]
# ## Tokenizing the lyrics

# %%
def identify_tokens(row):
    Lyrics = row['llr']
    tokens = nltk.word_tokenize(Lyrics)
    # taken only words (not punctuation)
    token_words = [w for w in tokens if w.isalpha()]
    return token_words

lyric_filtered['llr'] = lyric_filtered.apply(identify_tokens, axis=1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
lyric_filtered['lyrics'] = lyric_filtered['lyrics'].str.strip('\n')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
lyric_filtered.count()
# Out:
# song      30000
# year      30000
# artist    30000
# genre     30000
# lyrics    30000
# llr       30000
# dtype: int64

# %% [markdown]
# ## Removing Stop Words

# %%
stops = set(nltk.corpus.stopwords.words("english"))
t = ('ive','youre','verse','im','yo','oh','Oh','yea','ah','sham',
     'if','If','For','Then','It','isnt','Im','sam','mrs','yea',
     'sloopy','hey','mr','woah','aint','yah','Verse','uhuh','im',
     'dont', 'know','just', 'got', 'yeah','make','let','come','wanna',
     'ill','aint','tell','ya','get', 'go','see', 'one', 'take', 'la',
     'ooh','id','youll','na','theyll','ever','theres','youve','I','i',
     'Ay','Hello','hello','ca','is','the','ai','gon','que','wan','wo','chorus')
stops.update(t)


def remove_stops(row):
    my_list = row['llr']
    meaningful_words = [w for w in my_list if not w in stops]
    return (meaningful_words)

lyric_filtered['llr'] = lyric_filtered.apply(remove_stops, axis=1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
lyric_filtered.head()
# Out:
#               song  year           artist genre  \
# 0        ego-remix  2009  beyonce-knowles   Pop
# 1     then-tell-me  2009  beyonce-knowles   Pop
# 2          honesty  2009  beyonce-knowles   Pop
# 3  you-are-my-rock  2009  beyonce-knowles   Pop
# 4    black-culture  2009  beyonce-knowles   Pop
#
#                                               lyrics  \
# 0  Oh baby how you doing\nYou know Im gonna cut r...
# 1  playin everything so easy\nits like you seem s...
# 2  If you search\nFor tenderness\nIt isnt hard to...
# 3  Oh oh oh I oh oh oh I\nVerse \nIf I wrote a bo...
# 4  Party the people the people the party its popp...
#
#                                                  llr
# 0  [baby, gon, cut, right, chase, women, made, li...
# 1  [playin, everything, easy, like, seem, sure, s...
# 2  [search, tenderness, hard, find, love, need, l...
# 3  [wrote, book, stand, title, book, would, life,...
# 4  [party, people, people, party, popping, sittin...

# %% [markdown]
# ## Drop songs with na fields

# %%
Lyrics_Genre.dropna(inplace = True)

# %% [markdown]
# ## Filtering lyrincs having length more than or equal to  20

# %%
lyric_more = lyric_filtered[lyric_filtered['lyrics'].str.len() >= 10]

# %% [markdown]
# ## Saving the Clean Dataset

# %%
lyric_more.to_csv('CleanedData.csv')

# %%
pd.read_csv('CleanedData.csv')
# Out:
#        Unnamed: 0                                               song  year  \
# 0               0                                          ego-remix  2009
# 1               1                                       then-tell-me  2009
# 2               2                                            honesty  2009
# 3               3                                    you-are-my-rock  2009
# 4               4                                      black-culture  2009
# 5               5                             all-i-could-do-was-cry  2009
# 6               6                                 once-in-a-lifetime  2009
# 7               7                                            waiting  2009
# 8               8                                          slow-love  2009
# 9               9                              why-don-t-you-love-me  2009
# 10             10                                      save-the-hero  2009
# 11             11                                          telephone  2009
# 12             12                                    ice-cream-truck  2009
# 13             13                             no-broken-hearted-girl  2009
# 14             14                                            control  2009
# 15             15                                      i-m-alone-now  2009
# 16             16                                             poison  2009
# 17             17                                   world-wide-women  2007
# 18             18                                     beautiful-liar  2007
# 19             19                             beautiful-liar-spanish  2007
# 20             20                   beautiful-liar-spanglish-version  2007
# 21             21                                          bienvenue  2007
# 22             22                                beutiful-liar-remix  2007
# 23             23  he-still-loves-me-f-choir-from-fighting-tempta...  2007
# 24             24                                    bello-embustero  2007
# 25             25                                         irreplable  2007
# 26             26                                      the-first-day  2007
# 27             27                                             my-man  2007
# 28             28                                 what-s-it-gonna-be  2007
# 29             29                                                 if  2007
# ...           ...                                                ...   ...
# 21322       29956                                  introduction-skip  2005
# 21323       29957                                           hard-way  2005
# 21324       29958                                       red-to-black  2005
# 21325       29959                                     feel-like-home  2005
# 21326       29960                                          right-now  2005
# 21327       29961                                  remember-the-name  2005
# 21328       29962                                          in-stereo  2005
# 21329       29963                                     where-d-you-go  2005
# 21330       29964                                              kenji  2005
# 21331       29965                                          petrified  2005
# 21332       29966                                          back-home  2005
# 21333       29967                                         cigarettes  2005
# 21334       29968                                        be-somebody  2005
# 21335       29969                                        get-me-gone  2005
# 21336       29970                                  slip-out-the-back  2005
# 21337       29971                                          high-road  2005
# 21338       29972                                        100-degrees  2006
# 21339       29973                                         bloc-party  2006
# 21340       29974                                              dolla  2006
# 21341       29975                                            s-c-o-m  2006
# 21342       29976                                spraypaint-ink-pens  2006
# 21343       29977                                     do-what-we-did  2011
# 21344       29978                                            welcome  2015
# 21345       29979                                 tools-of-the-trade  2008
# 21346       29980                                          dedicated  2008
# 21347       29981                                       spell-it-out  2014
# 21348       29982                                    start-it-all-up  2014
# 21349       29983                                         lights-out  2009
# 21350       29984                        can-i-call-you-up-ring-ring  2012
# 21351       29985                                     l-ultima-festa  2016
#
#                 artist          genre  \
# 0      beyonce-knowles            Pop
# 1      beyonce-knowles            Pop
# 2      beyonce-knowles            Pop
# 3      beyonce-knowles            Pop
# 4      beyonce-knowles            Pop
# 5      beyonce-knowles            Pop
# 6      beyonce-knowles            Pop
# 7      beyonce-knowles            Pop
# 8      beyonce-knowles            Pop
# 9      beyonce-knowles            Pop
# 10     beyonce-knowles            Pop
# 11     beyonce-knowles            Pop
# 12     beyonce-knowles            Pop
# 13     beyonce-knowles            Pop
# 14     beyonce-knowles            Pop
# 15     beyonce-knowles            Pop
# 16     beyonce-knowles            Pop
# 17     beyonce-knowles            Pop
# 18     beyonce-knowles            Pop
# 19     beyonce-knowles            Pop
# 20     beyonce-knowles            Pop
# 21     beyonce-knowles            Pop
# 22     beyonce-knowles            Pop
# 23     beyonce-knowles            Pop
# 24     beyonce-knowles            Pop
# 25     beyonce-knowles            Pop
# 26     beyonce-knowles            Pop
# 27     beyonce-knowles            Pop
# 28     beyonce-knowles            Pop
# 29     beyonce-knowles            Pop
# ...                ...            ...
# 21322       fort-minor           Rock
# 21323       fort-minor           Rock
# 21324       fort-minor           Rock
# 21325       fort-minor           Rock
# 21326       fort-minor           Rock
# 21327       fort-minor           Rock
# 21328       fort-minor           Rock
# 21329       fort-minor           Rock
# 21330       fort-minor           Rock
# 21331       fort-minor           Rock
# 21332       fort-minor           Rock
# 21333       fort-minor           Rock
# 21334       fort-minor           Rock
# 21335       fort-minor           Rock
# 21336       fort-minor           Rock
# 21337       fort-minor           Rock
# 21338       fort-minor           Rock
# 21339       fort-minor           Rock
# 21340       fort-minor           Rock
# 21341       fort-minor           Rock
# 21342       fort-minor           Rock
# 21343       fort-minor           Rock
# 21344       fort-minor           Rock
# 21345       fort-minor           Rock
# 21346       fort-minor           Rock
# 21347       fort-minor           Rock
# 21348       fort-minor           Rock
# 21349            cosmo  Not Available
# 21350            cosmo  Not Available
# 21351            cosmo  Not Available
#
#                                                   lyrics  \
# 0      Oh baby how you doing\nYou know Im gonna cut r...
# 1      playin everything so easy\nits like you seem s...
# 2      If you search\nFor tenderness\nIt isnt hard to...
# 3      Oh oh oh I oh oh oh I\nVerse \nIf I wrote a bo...
# 4      Party the people the people the party its popp...
# 5      I heard\nChurch bells ringing\nI heard\nA choi...
# 6      This is just another day that I would spend\nW...
# 7      Waiting waiting waiting waiting\nWaiting waiti...
# 8      Verse \nI read all of the magazines\nwhile wai...
# 9      Nnnow honey\nYou better sit down and look arou...
# 10     I lay alone awake at night\nSorrow fills my ey...
# 11     Hello hello baby you called\nI cant hear a thi...
# 12     Feels like Im losing my mind\nLove is so hard ...
# 13     Youre everything I thought you never were\nAnd...
# 14     I gotta give up\nto quite the storm that rages...
# 15     It really hurts to say this yes it does\nBut a...
# 16     Youre bad for me I clearly get it\nI dont see ...
# 17     Chorus\nIm a world wide woman WWW you can log ...
# 18     Ay\nAy\nAy Nobody likes to be played\nOh Beyon...
# 19     Ay Ay\nNobody likes being played\nAy\nOh Beyon...
# 20     Ay Ay\nNobody likes being played\nAy\nOh Beyon...
# 21     Beyonc  Intro\nBeyonce\nIAM\nWelcome\nWelcome\...
# 22     Ay Ay\nNobody likes being played\nAy\nOh Beyon...
# 23     Took me a while but Im finally here\nSo I just...
# 24     Ay Ay Ay\nOh Beyonc Beyonc\nOh Beyonc Beyonc\n...
# 25     To the left to the left\nTo the left to the le...
# 26     Remember the first day when I saw your face\nr...
# 27     you say that hes wrong\nyou say that hes no go...
# 28     st verse\nhey you whats the deal its popping u...
# 29     He is always laughin and flirting with me\nAnd...
# ...                                                  ...
# 21322  What up Mike\nUm we almost ready now my nigger...
# 21323  Come with me\nLet me walk you through the worl...
# 21324  I had a friend named Victor\nThe two of us use...
# 21325  These days are dark and the nights are cold\nP...
# 21326  Someone right now is leaving their apartment\n...
# 21327  You ready Lets go\nYeah for those of you that ...
# 21328  JayZ\nThat beat is hot\nMike\nThis is how it g...
# 21329  Whered you go\nI miss you so\nSeems like its b...
# 21330  My father came from Japan in  He was fifteen w...
# 21331  Yall are nnnot ready yo\nNot areready yo\nWe a...
# 21332  Back home\nEverybodys searching for somethin\n...
# 21333  Man I love this rap game mainly cause its cool...
# 21334  Mike\nThis is a story of them against us win o...
# 21335  The dude he said that like when we were making...
# 21336  You know me\nI used to get caught up in everyd...
# 21337  Lets go yall\nThese people are running off at ...
# 21338  Mike\nYo you ready do this Ok\nCome on Lets go...
# 21339  Green Lantern\nvasion\nMike\nHey Ap why dont y...
# 21340  Mike\nYeah like that Yall\nUh huh whoo like th...
# 21341  Ugh Shinoda thats right Ryu\nCelph Titled yeah...
# 21342  Fort Minor Minor\nFort Minor Minor Minor\nUh s...
# 21343  If anybodys out there listenin to this broadca...
# 21344  Welcome yeah its been a long minute\nLet me br...
# 21345  Mike\nI can make a loop out of anything work\n...
# 21346  I have a dream\nOf a scene between the green h...
# 21347  Yo its like a triplestaged darkness listen and...
# 21348  Yo\nGive me a second Ill write about my pain f...
# 21349  Yeahoh\nLights out x\nIm late to the party cau...
# 21350  Cosmo Ft Ryan Moore  Can I Call You Up Ring Ri...
# 21351  Via Ã ora di andare via\nIniziano a guardarci ...
#
#                                                      llr
# 0      ['baby', 'gon', 'cut', 'right', 'chase', 'wome...
# 1      ['playin', 'everything', 'easy', 'like', 'seem...
# 2      ['search', 'tenderness', 'hard', 'find', 'love...
# 3      ['wrote', 'book', 'stand', 'title', 'book', 'w...
# 4      ['party', 'people', 'people', 'party', 'poppin...
# 5      ['heard', 'church', 'bells', 'ringing', 'heard...
# 6      ['another', 'day', 'would', 'spend', 'waitin',...
# 7      ['waiting', 'waiting', 'waiting', 'waiting', '...
# 8      ['read', 'magazines', 'waiting', 'around', 'sa...
# 9      ['honey', 'better', 'sit', 'look', 'around', '...
# 10     ['lay', 'alone', 'awake', 'night', 'sorrow', '...
# 11     ['hello', 'hello', 'baby', 'called', 'ca', 'he...
# 12     ['feels', 'like', 'losing', 'mind', 'love', 'h...
# 13     ['everything', 'thought', 'never', 'nothing', ...
# 14     ['ta', 'give', 'quite', 'storm', 'rages', 'ins...
# 15     ['really', 'hurts', 'say', 'yes', 'sweet', 'lo...
# 16     ['bad', 'clearly', 'something', 'good', 'could...
# 17     ['chorus', 'world', 'wide', 'woman', 'www', 'l...
# 18     ['ay', 'ay', 'ay', 'nobody', 'likes', 'played'...
# 19     ['ay', 'ay', 'nobody', 'likes', 'played', 'ay'...
# 20     ['ay', 'ay', 'nobody', 'likes', 'played', 'ay'...
# 21     ['beyonc', 'intro', 'beyonce', 'iam', 'welcome...
# 22     ['ay', 'ay', 'nobody', 'likes', 'played', 'ay'...
# 23     ['took', 'finally', 'wan', 'testify', 'crystal...
# 24     ['ay', 'ay', 'ay', 'beyonc', 'beyonc', 'beyonc...
# 25     ['left', 'left', 'left', 'left', 'left', 'left...
# 26     ['remember', 'first', 'day', 'saw', 'face', 'r...
# 27     ['say', 'wrong', 'say', 'good', 'leave', 'em',...
# 28     ['deal', 'popping', 'wan', 'good', 'time', 'tr...
# 29     ['always', 'laughin', 'flirting', 'act', 'like...
# ...                                                  ...
# 21322  ['mike', 'um', 'almost', 'ready', 'nigger', 'e...
# 21323  ['walk', 'world', 'currently', 'stay', 'look',...
# 21324  ['friend', 'named', 'victor', 'two', 'us', 'us...
# 21325  ['days', 'dark', 'nights', 'cold', 'people', '...
# 21326  ['someone', 'right', 'leaving', 'apartment', '...
# 21327  ['ready', 'wan', 'like', 'ten', 'percent', 'lu...
# 21328  ['beat', 'hot', 'mike', 'goes', 'welcome', 'sh...
# 21329  ['miss', 'seems', 'like', 'forever', 'gone', '...
# 21330  ['father', 'came', 'japan', 'fifteen', 'immigr...
# 21331  ['ready', 'drop', 'steady', 'like', 'everybody...
# 21332  ['back', 'home', 'everybody', 'searching', 'fi...
# 21333  ['man', 'love', 'rap', 'game', 'mainly', 'caus...
# 21334  ['mike', 'story', 'us', 'win', 'lose', 'forcin...
# 21335  ['dude', 'said', 'like', 'making', 'first', 'l...
# 21336  ['used', 'caught', 'everyday', 'life', 'trying...
# 21337  ['lets', 'people', 'running', 'mouth', 'trying...
# 21338  ['mike', 'ready', 'ok', 'green', 'lantern', 'i...
# 21339  ['green', 'lantern', 'vasion', 'mike', 'ap', '...
# 21340  ['mike', 'like', 'uh', 'huh', 'whoo', 'like', ...
# 21341  ['ugh', 'shinoda', 'right', 'ryu', 'celph', 't...
# 21342  ['fort', 'minor', 'minor', 'fort', 'minor', 'm...
# 21343  ['anybody', 'listenin', 'broadcast', 'mine', '...
# 21344  ['welcome', 'long', 'minute', 'break', 'still'...
# 21345  ['mike', 'loop', 'anything', 'work', 'surprise...
# 21346  ['dream', 'scene', 'green', 'hills', 'clouds',...
# 21347  ['like', 'darkness', 'listen', 'drift', 'every...
# 21348  ['give', 'second', 'write', 'pain', 'pages', '...
# 21349  ['yeahoh', 'lights', 'late', 'party', 'cause',...
# 21350  ['cosmo', 'ft', 'ryan', 'moore', 'call', 'ring...
# 21351  ['via', 'ora', 'di', 'andare', 'via', 'inizian...
#
# [21352 rows x 7 columns]

# %% [markdown]
# ## Drop the songds with Genre not Available
#
#     Filter the songs from 2001 to 2016

# %%
lyric_more = lyric_more[lyric_more.genre !='Not Available']
lyric_more = lyric_more[lyric_more['year'].isin(['2001','2002','2003','2004','2005','2006','2007',
                                                 '2008','2009','2010','2011','2012','2013','2014','2015'
                                                '2016']) ]

# %%
lyric_more
# Out:
#                                                     song  year  \
# 0                                              ego-remix  2009
# 1                                           then-tell-me  2009
# 2                                                honesty  2009
# 3                                        you-are-my-rock  2009
# 4                                          black-culture  2009
# 5                                 all-i-could-do-was-cry  2009
# 6                                     once-in-a-lifetime  2009
# 7                                                waiting  2009
# 8                                              slow-love  2009
# 9                                  why-don-t-you-love-me  2009
# 10                                         save-the-hero  2009
# 11                                             telephone  2009
# 12                                       ice-cream-truck  2009
# 13                                no-broken-hearted-girl  2009
# 14                                               control  2009
# 15                                         i-m-alone-now  2009
# 16                                                poison  2009
# 17                                      world-wide-women  2007
# 18                                        beautiful-liar  2007
# 19                                beautiful-liar-spanish  2007
# 20                      beautiful-liar-spanglish-version  2007
# 21                                             bienvenue  2007
# 22                                   beutiful-liar-remix  2007
# 23     he-still-loves-me-f-choir-from-fighting-tempta...  2007
# 24                                       bello-embustero  2007
# 25                                            irreplable  2007
# 26                                         the-first-day  2007
# 27                                                my-man  2007
# 28                                    what-s-it-gonna-be  2007
# 29                                                    if  2007
# ...                                                  ...   ...
# 29952                                  respect-4-grandma  2007
# 29953                                             battle  2005
# 29954                                         believe-me  2005
# 29955                                      there-they-go  2005
# 29956                                  introduction-skip  2005
# 29957                                           hard-way  2005
# 29958                                       red-to-black  2005
# 29959                                     feel-like-home  2005
# 29960                                          right-now  2005
# 29961                                  remember-the-name  2005
# 29962                                          in-stereo  2005
# 29963                                     where-d-you-go  2005
# 29964                                              kenji  2005
# 29965                                          petrified  2005
# 29966                                          back-home  2005
# 29967                                         cigarettes  2005
# 29968                                        be-somebody  2005
# 29969                                        get-me-gone  2005
# 29970                                  slip-out-the-back  2005
# 29971                                          high-road  2005
# 29972                                        100-degrees  2006
# 29973                                         bloc-party  2006
# 29974                                              dolla  2006
# 29975                                            s-c-o-m  2006
# 29976                                spraypaint-ink-pens  2006
# 29977                                     do-what-we-did  2011
# 29979                                 tools-of-the-trade  2008
# 29980                                          dedicated  2008
# 29981                                       spell-it-out  2014
# 29982                                    start-it-all-up  2014
#
#                 artist genre  \
# 0      beyonce-knowles   Pop
# 1      beyonce-knowles   Pop
# 2      beyonce-knowles   Pop
# 3      beyonce-knowles   Pop
# 4      beyonce-knowles   Pop
# 5      beyonce-knowles   Pop
# 6      beyonce-knowles   Pop
# 7      beyonce-knowles   Pop
# 8      beyonce-knowles   Pop
# 9      beyonce-knowles   Pop
# 10     beyonce-knowles   Pop
# 11     beyonce-knowles   Pop
# 12     beyonce-knowles   Pop
# 13     beyonce-knowles   Pop
# 14     beyonce-knowles   Pop
# 15     beyonce-knowles   Pop
# 16     beyonce-knowles   Pop
# 17     beyonce-knowles   Pop
# 18     beyonce-knowles   Pop
# 19     beyonce-knowles   Pop
# 20     beyonce-knowles   Pop
# 21     beyonce-knowles   Pop
# 22     beyonce-knowles   Pop
# 23     beyonce-knowles   Pop
# 24     beyonce-knowles   Pop
# 25     beyonce-knowles   Pop
# 26     beyonce-knowles   Pop
# 27     beyonce-knowles   Pop
# 28     beyonce-knowles   Pop
# 29     beyonce-knowles   Pop
# ...                ...   ...
# 29952       fort-minor  Rock
# 29953       fort-minor  Rock
# 29954       fort-minor  Rock
# 29955       fort-minor  Rock
# 29956       fort-minor  Rock
# 29957       fort-minor  Rock
# 29958       fort-minor  Rock
# 29959       fort-minor  Rock
# 29960       fort-minor  Rock
# 29961       fort-minor  Rock
# 29962       fort-minor  Rock
# 29963       fort-minor  Rock
# 29964       fort-minor  Rock
# 29965       fort-minor  Rock
# 29966       fort-minor  Rock
# 29967       fort-minor  Rock
# 29968       fort-minor  Rock
# 29969       fort-minor  Rock
# 29970       fort-minor  Rock
# 29971       fort-minor  Rock
# 29972       fort-minor  Rock
# 29973       fort-minor  Rock
# 29974       fort-minor  Rock
# 29975       fort-minor  Rock
# 29976       fort-minor  Rock
# 29977       fort-minor  Rock
# 29979       fort-minor  Rock
# 29980       fort-minor  Rock
# 29981       fort-minor  Rock
# 29982       fort-minor  Rock
#
#                                                   lyrics  \
# 0      Oh baby how you doing\nYou know Im gonna cut r...
# 1      playin everything so easy\nits like you seem s...
# 2      If you search\nFor tenderness\nIt isnt hard to...
# 3      Oh oh oh I oh oh oh I\nVerse \nIf I wrote a bo...
# 4      Party the people the people the party its popp...
# 5      I heard\nChurch bells ringing\nI heard\nA choi...
# 6      This is just another day that I would spend\nW...
# 7      Waiting waiting waiting waiting\nWaiting waiti...
# 8      Verse \nI read all of the magazines\nwhile wai...
# 9      Nnnow honey\nYou better sit down and look arou...
# 10     I lay alone awake at night\nSorrow fills my ey...
# 11     Hello hello baby you called\nI cant hear a thi...
# 12     Feels like Im losing my mind\nLove is so hard ...
# 13     Youre everything I thought you never were\nAnd...
# 14     I gotta give up\nto quite the storm that rages...
# 15     It really hurts to say this yes it does\nBut a...
# 16     Youre bad for me I clearly get it\nI dont see ...
# 17     Chorus\nIm a world wide woman WWW you can log ...
# 18     Ay\nAy\nAy Nobody likes to be played\nOh Beyon...
# 19     Ay Ay\nNobody likes being played\nAy\nOh Beyon...
# 20     Ay Ay\nNobody likes being played\nAy\nOh Beyon...
# 21     Beyonc  Intro\nBeyonce\nIAM\nWelcome\nWelcome\...
# 22     Ay Ay\nNobody likes being played\nAy\nOh Beyon...
# 23     Took me a while but Im finally here\nSo I just...
# 24     Ay Ay Ay\nOh Beyonc Beyonc\nOh Beyonc Beyonc\n...
# 25     To the left to the left\nTo the left to the le...
# 26     Remember the first day when I saw your face\nr...
# 27     you say that hes wrong\nyou say that hes no go...
# 28     st verse\nhey you whats the deal its popping u...
# 29     He is always laughin and flirting with me\nAnd...
# ...                                                  ...
# 29952  Are we recording right now\nYea were recording...
# 29953  Times up hold up aight Celph you got  seconds ...
# 29954  Believe Me\nI guess that this is where weve co...
# 29955  Mike\nOne time  for my Machine Shop crew and t...
# 29956  What up Mike\nUm we almost ready now my nigger...
# 29957  Come with me\nLet me walk you through the worl...
# 29958  I had a friend named Victor\nThe two of us use...
# 29959  These days are dark and the nights are cold\nP...
# 29960  Someone right now is leaving their apartment\n...
# 29961  You ready Lets go\nYeah for those of you that ...
# 29962  JayZ\nThat beat is hot\nMike\nThis is how it g...
# 29963  Whered you go\nI miss you so\nSeems like its b...
# 29964  My father came from Japan in  He was fifteen w...
# 29965  Yall are nnnot ready yo\nNot areready yo\nWe a...
# 29966  Back home\nEverybodys searching for somethin\n...
# 29967  Man I love this rap game mainly cause its cool...
# 29968  Mike\nThis is a story of them against us win o...
# 29969  The dude he said that like when we were making...
# 29970  You know me\nI used to get caught up in everyd...
# 29971  Lets go yall\nThese people are running off at ...
# 29972  Mike\nYo you ready do this Ok\nCome on Lets go...
# 29973  Green Lantern\nvasion\nMike\nHey Ap why dont y...
# 29974  Mike\nYeah like that Yall\nUh huh whoo like th...
# 29975  Ugh Shinoda thats right Ryu\nCelph Titled yeah...
# 29976  Fort Minor Minor\nFort Minor Minor Minor\nUh s...
# 29977  If anybodys out there listenin to this broadca...
# 29979  Mike\nI can make a loop out of anything work\n...
# 29980  I have a dream\nOf a scene between the green h...
# 29981  Yo its like a triplestaged darkness listen and...
# 29982  Yo\nGive me a second Ill write about my pain f...
#
#                                                      llr
# 0      [baby, gon, cut, right, chase, women, made, li...
# 1      [playin, everything, easy, like, seem, sure, s...
# 2      [search, tenderness, hard, find, love, need, l...
# 3      [wrote, book, stand, title, book, would, life,...
# 4      [party, people, people, party, popping, sittin...
# 5      [heard, church, bells, ringing, heard, choir, ...
# 6      [another, day, would, spend, waitin, right, st...
# 7      [waiting, waiting, waiting, waiting, waiting, ...
# 8      [read, magazines, waiting, around, said, could...
# 9      [honey, better, sit, look, around, must, bumpe...
# 10     [lay, alone, awake, night, sorrow, fills, eyes...
# 11     [hello, hello, baby, called, ca, hear, thing, ...
# 12     [feels, like, losing, mind, love, hard, find, ...
# 13     [everything, thought, never, nothing, like, th...
# 14     [ta, give, quite, storm, rages, inside, way, h...
# 15     [really, hurts, say, yes, sweet, love, ai, eno...
# 16     [bad, clearly, something, good, could, loving,...
# 17     [chorus, world, wide, woman, www, log, anywher...
# 18     [ay, ay, ay, nobody, likes, played, beyonce, b...
# 19     [ay, ay, nobody, likes, played, ay, beyonc, be...
# 20     [ay, ay, nobody, likes, played, ay, beyonce, b...
# 21     [beyonc, intro, beyonce, iam, welcome, welcome...
# 22     [ay, ay, nobody, likes, played, ay, beyonc, be...
# 23     [took, finally, wan, testify, crystal, clear, ...
# 24     [ay, ay, ay, beyonc, beyonc, beyonc, beyonc, m...
# 25     [left, left, left, left, left, left, everythin...
# 26     [remember, first, day, saw, face, remember, fi...
# 27     [say, wrong, say, good, leave, em, alone, gon,...
# 28     [deal, popping, wan, good, time, tryna, chill,...
# 29     [always, laughin, flirting, act, like, even, c...
# ...                                                  ...
# 29952  [recording, right, recording, cant, right, gra...
# 29953  [time, hold, aight, celph, seconds, ready, alr...
# 29954  [believe, guess, want, believe, wo, believe, r...
# 29955  [mike, time, machine, shop, crew, two, times, ...
# 29956  [mike, um, almost, ready, nigger, el, presiden...
# 29957  [walk, world, currently, stay, look, around, m...
# 29958  [friend, named, victor, two, us, used, hang, e...
# 29959  [days, dark, nights, cold, people, acting, lik...
# 29960  [someone, right, leaving, apartment, looking, ...
# 29961  [ready, wan, like, ten, percent, luck, twenty,...
# 29962  [beat, hot, mike, goes, welcome, show, wired, ...
# 29963  [miss, seems, like, forever, gone, said, days,...
# 29964  [father, came, japan, fifteen, immigrated, jap...
# 29965  [ready, drop, steady, like, everybody, petrifi...
# 29966  [back, home, everybody, searching, find, whole...
# 29967  [man, love, rap, game, mainly, cause, cool, ad...
# 29968  [mike, story, us, win, lose, forcing, feet, so...
# 29969  [dude, said, like, making, first, linkin, park...
# 29970  [used, caught, everyday, life, trying, day, co...
# 29971  [lets, people, running, mouth, trying, convinc...
# 29972  [mike, ready, ok, green, lantern, invasion, ev...
# 29973  [green, lantern, vasion, mike, ap, uhthe, intr...
# 29974  [mike, like, uh, huh, whoo, like, fort, minor,...
# 29975  [ugh, shinoda, right, ryu, celph, titled, demi...
# 29976  [fort, minor, minor, fort, minor, minor, minor...
# 29977  [anybody, listenin, broadcast, mine, ladies, g...
# 29979  [mike, loop, anything, work, surprised, guys, ...
# 29980  [dream, scene, green, hills, clouds, pull, awa...
# 29981  [like, darkness, listen, drift, every, muscle,...
# 29982  [give, second, write, pain, pages, head, full,...
#
# [16764 rows x 6 columns]

# %%
import seaborn as sns

# %% [markdown]
# ## Famous Genre of the Music

# %%
pp = sns.countplot(x='genre',hue='genre',data=lyric_more,palette="Set3",saturation=1)
sns.set(rc={'figure.figsize':(25,20)})

# %%
(lyric_more.groupby(['genre']).count()['song']).plot.line()

# %%
lyric_gnre_year =(lyric_more.groupby(['genre','year']).count()['song']).to_frame()

# %%
lyric_gnre_year
# Out:
#                  song
# genre      year
# Country    2001     1
#            2006    19
#            2007   489
#            2008   112
#            2009    34
#            2010     5
#            2011     9
#            2012    18
#            2013     7
#            2014    12
# Electronic 2001    14
#            2002    12
#            2003     4
#            2005    12
#            2006   185
#            2007   129
#            2008    67
#            2009    26
#            2010    96
#            2011    49
#            2012    38
#            2013    53
#            2014    67
# Folk       2001    14
#            2002    17
#            2005    29
#            2006    57
#            2007    78
#            2008    45
#            2009    22
# ...               ...
# Pop        2008   310
#            2009   275
#            2010   107
#            2011   202
#            2012   218
#            2013   193
#            2014   278
# R&B        2006    10
#            2007    26
#            2008    36
#            2009     4
#            2010     5
#            2011    17
#            2012     4
#            2013    12
#            2014     2
# Rock       2001    56
#            2002    71
#            2003    34
#            2004    80
#            2005   231
#            2006  2434
#            2007  2536
#            2008   745
#            2009   322
#            2010   326
#            2011   115
#            2012   244
#            2013   204
#            2014   255
#
# [123 rows x 1 columns]

# %%
l= lyric_gnre_year.reset_index()

# %% [markdown]
# ## Count of song per genre and Year

# %%
import seaborn as sns
palette ={"Rock":"C0","Country":"C1","Electronic":"C2","Folk":"C3","Hip-Hop":"C4","Indie":"C5",
         "Jazz":"C6","Metal":"C7","Other":"C8","Pop":"C9","R&B":"C10"}
sns.set(font_scale=1)
#sns.set(rc={'figure.figsize':(100,25)})
g=sns.relplot(x="year", y="song", hue="genre",kind='line', data=l, palette=palette)
g.fig.set_figheight(20)
g.fig.set_figwidth(25)

# %% [markdown]
# ## Checking the length of each song

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (8,6)

df = pd.DataFrame(columns=('artist', 'words'))
i=0
for artist in lyric_more.song:
    f = lyric_more.llr
    num_words = []
    all_text = ''
    for sentence in f:
        this_sentence = sentence
        num_words_this = len(this_sentence)
        num_words.append(num_words_this) 
     
    df.loc[i] = (artist)
    i+=1

# %%
df['words']=num_words

# %%
df['genre'] = lyric_more['genre']

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                                                   artist  words    genre
# 0                                              ego-remix    164      Pop
# 1                                           then-tell-me     97      Pop
# 2                                                honesty     67      Pop
# 3                                        you-are-my-rock    182      Pop
# 4                                          black-culture    114      Pop
# 5                                 all-i-could-do-was-cry     59      Pop
# 6                                     once-in-a-lifetime    100      Pop
# 7                                                waiting    178      Pop
# 8                                              slow-love    210      Pop
# 9                                  why-don-t-you-love-me    114      Pop
# 10                                         save-the-hero    102      Pop
# 11                                             telephone    285      Pop
# 12                                       ice-cream-truck    112      Pop
# 13                                no-broken-hearted-girl    169      Pop
# 14                                               control     98      Pop
# 15                                         i-m-alone-now     79      Pop
# 16                                                poison    198      Pop
# 17                                      world-wide-women    227      Pop
# 18                                        beautiful-liar    133      Pop
# 19                                beautiful-liar-spanish    209      Pop
# 20                      beautiful-liar-spanglish-version    209      Pop
# 21                                             bienvenue    566      Pop
# 22                                   beutiful-liar-remix    209      Pop
# 23     he-still-loves-me-f-choir-from-fighting-tempta...    185      Pop
# 24                                       bello-embustero    249      Pop
# 25                                            irreplable    170      Pop
# 26                                         the-first-day    176      Pop
# 27                                                my-man    179      Pop
# 28                                    what-s-it-gonna-be     94      Pop
# 29                                                    if     99      Pop
# ...                                                  ...    ...      ...
# 16629                         trouble-in-the-amen-corner    184     Rock
# 16630                                                 us     97    Metal
# 16631                                  kiss-you-all-over    102    Metal
# 16632                                       come-sundown     47      Pop
# 16638    if-only-you-d-of-happened-to-me-a-long-time-ago     37  Hip-Hop
# 16662                                  talk-to-her-heart     79     Folk
# 16670                                roller-coaster-ride     87     Folk
# 16672                               sugar-in-your-coffee     91     Folk
# 16673                                    great-great-day     62     Folk
# 16675                        i-m-so-lonesome-i-could-cry     49     Folk
# 16676                                               wine     95     Folk
# 16684                                  as-long-as-i-live     40     Folk
# 16686                                               born     67     Folk
# 16687                             country-lay-on-my-mind    129     Folk
# 16690              tomorrow-s-gonna-be-better-than-today    102     Folk
# 16691                        when-liking-turns-to-loving     66     Folk
# 16692                            something-to-believe-in     76     Folk
# 16693                                          rocky-top     90     Folk
# 16694                                      we-missed-you     52     Folk
# 16695                            love-is-a-fragile-thing     84     Folk
# 16696                                       stay-with-me     50     Folk
# 16697                            swing-low-sweet-chariot     96     Folk
# 16748                                          back-home    198     Folk
# 16749                                         cigarettes    178     Folk
# 16750                                        be-somebody    205     Folk
# 16751                                        get-me-gone    158     Folk
# 16754                                        100-degrees    149     Folk
# 16755                                         bloc-party    304     Folk
# 16757                                            s-c-o-m    265     Folk
# 16758                                spraypaint-ink-pens    378     Folk
#
# [9497 rows x 3 columns]

# %% [markdown]
# ## Length of song per genre

# %%
fig, ax = plt.subplots(figsize=(40,20))
palette ={"Rock":"C0","Country":"C1","Electronic":"C2","Folk":"C3","Hip-Hop":"C4","Indie":"C5",
         "Jazz":"C6","Metal":"C7","Other":"C8","Pop":"C9","R&B":"C10"}
sns.stripplot(x='genre',y='words',hue='genre',data=df,palette="Set1",size=8,jitter=True,dodge=False,ax=ax)

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (50,20)
plt.rcParams['axes.linewidth'] = 0.4
fig, ax=plt.subplots()
l.groupby('genre').plot(x='year',y='song',legend=False,ax=ax)
# Out:
# genre
# Country       AxesSubplot(0.125,0.125;0.775x0.755)
# Electronic    AxesSubplot(0.125,0.125;0.775x0.755)
# Folk          AxesSubplot(0.125,0.125;0.775x0.755)
# Hip-Hop       AxesSubplot(0.125,0.125;0.775x0.755)
# Indie         AxesSubplot(0.125,0.125;0.775x0.755)
# Jazz          AxesSubplot(0.125,0.125;0.775x0.755)
# Metal         AxesSubplot(0.125,0.125;0.775x0.755)
# Other         AxesSubplot(0.125,0.125;0.775x0.755)
# Pop           AxesSubplot(0.125,0.125;0.775x0.755)
# R&B           AxesSubplot(0.125,0.125;0.775x0.755)
# Rock          AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
df_top5.transpose()
# Out:
# genre  Rock       Metal Rock  Pop Metal  Pop           Hip-Hop  ... Country  \
# year   2007  2006  2007 2008 2006  2006 2007 2014 2008    2006  ...    2010
# song   1830  1672   553  523  445   359  308  243  229     192  ...       5
#
# genre Folk  Pop Indie Electronic  R&B      Other Indie Country
# year  2014 2005  2013       2003 2014 2010  2006  2009    2001
# song     4    4     3          3    1    1     1     1       1
#
# [1 rows x 116 columns]

# %%
lyric_more.groupby(['genre']).count().plot(kind='bar',figsize=(15,20))

# %%
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

# %%
str2 = ''
for index, row in lyric_more.iterrows():
    ala=row['llr']
    
    str1=' '.join(ala)
    #print(str1)
    str2 = str1 +' '+ str2

# %%
len(str2)
# Out:
# 10545135

# %%
wordcloud = WordCloud(background_color="white", max_words=2000, 
                     contour_width=5, contour_color='steelblue',width=800,height=800,relative_scaling=0.3)

# %%
wordcloud.generate(str2)

# %%
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=800x800 at 0x133D370B8>

# %%
def plot_30_most_common_words(count_data, count_vectorizer):
    import matplotlib.pyplot as plt
    words = count_vectorizer.get_feature_names()
    total_counts = np.zeros(len(words))
    for t in count_data:
        total_counts+=t.toarray()[0]
    
    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:30]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words)) 
    
    plt.figure(2, figsize=(15, 15/1.6180))
    plt.subplot(title='30 most common words')
    sns.set_context("notebook", font_scale=1.25, rc={"lines.linewidth": 2.5})
    sns.barplot(x_pos, counts, palette='husl')
    plt.xticks(x_pos, words, rotation=90) 
    plt.xlabel('words')
    plt.ylabel('counts')
    plt.show()

# %%
df2 = pd.DataFrame(columns=('lr','w'))

# %%
num_wrd = []
for index, row in lyric_more.iterrows():
    al=row['llr']
    fullStr=' '.join(al)
    num_wrd.append(fullStr)

# %%
df2['lr'] = num_wrd

# %%
count_vectorizer = CountVectorizer(stop_words='english')

# %%
count_data = count_vectorizer.fit_transform(df2['lr'])

# %%
plot_30_most_common_words(count_data, count_vectorizer)

# %%
lyric_more.llr
# Out:
# 0        [baby, gon, cut, right, chase, women, made, li...
# 1        [playin, everything, easy, like, seem, sure, s...
# 2        [search, tenderness, hard, find, love, need, l...
# 3        [wrote, book, stand, title, book, would, life,...
# 4        [party, people, people, party, popping, sittin...
# 5        [heard, church, bells, ringing, heard, choir, ...
# 6        [another, day, would, spend, waitin, right, st...
# 7        [waiting, waiting, waiting, waiting, waiting, ...
# 8        [read, magazines, waiting, around, said, could...
# 9        [honey, better, sit, look, around, must, bumpe...
# 10       [lay, alone, awake, night, sorrow, fills, eyes...
# 11       [hello, hello, baby, called, ca, hear, thing, ...
# 12       [feels, like, losing, mind, love, hard, find, ...
# 13       [everything, thought, never, nothing, like, th...
# 14       [ta, give, quite, storm, rages, inside, way, h...
# 15       [really, hurts, say, yes, sweet, love, ai, eno...
# 16       [bad, clearly, something, good, could, loving,...
# 17       [chorus, world, wide, woman, www, log, anywher...
# 18       [ay, ay, ay, nobody, likes, played, beyonce, b...
# 19       [ay, ay, nobody, likes, played, ay, beyonc, be...
# 20       [ay, ay, nobody, likes, played, ay, beyonce, b...
# 21       [beyonc, intro, beyonce, iam, welcome, welcome...
# 22       [ay, ay, nobody, likes, played, ay, beyonc, be...
# 23       [took, finally, wan, testify, crystal, clear, ...
# 24       [ay, ay, ay, beyonc, beyonc, beyonc, beyonc, m...
# 25       [left, left, left, left, left, left, everythin...
# 26       [remember, first, day, saw, face, remember, fi...
# 27       [say, wrong, say, good, leave, em, alone, gon,...
# 28       [deal, popping, wan, good, time, tryna, chill,...
# 29       [always, laughin, flirting, act, like, even, c...
#                                ...
# 29952    [recording, right, recording, cant, right, gra...
# 29953    [time, hold, aight, celph, seconds, ready, alr...
# 29954    [believe, guess, want, believe, wo, believe, r...
# 29955    [mike, time, machine, shop, crew, two, times, ...
# 29956    [mike, um, almost, ready, nigger, el, presiden...
# 29957    [walk, world, currently, stay, look, around, m...
# 29958    [friend, named, victor, two, us, used, hang, e...
# 29959    [days, dark, nights, cold, people, acting, lik...
# 29960    [someone, right, leaving, apartment, looking, ...
# 29961    [ready, wan, like, ten, percent, luck, twenty,...
# 29962    [beat, hot, mike, goes, welcome, show, wired, ...
# 29963    [miss, seems, like, forever, gone, said, days,...
# 29964    [father, came, japan, fifteen, immigrated, jap...
# 29965    [ready, drop, steady, like, everybody, petrifi...
# 29966    [back, home, everybody, searching, find, whole...
# 29967    [man, love, rap, game, mainly, cause, cool, ad...
# 29968    [mike, story, us, win, lose, forcing, feet, so...
# 29969    [dude, said, like, making, first, linkin, park...
# 29970    [used, caught, everyday, life, trying, day, co...
# 29971    [lets, people, running, mouth, trying, convinc...
# 29972    [mike, ready, ok, green, lantern, invasion, ev...
# 29973    [green, lantern, vasion, mike, ap, uhthe, intr...
# 29974    [mike, like, uh, huh, whoo, like, fort, minor,...
# 29975    [ugh, shinoda, right, ryu, celph, titled, demi...
# 29976    [fort, minor, minor, fort, minor, minor, minor...
# 29977    [anybody, listenin, broadcast, mine, ladies, g...
# 29979    [mike, loop, anything, work, surprised, guys, ...
# 29980    [dream, scene, green, hills, clouds, pull, awa...
# 29981    [like, darkness, listen, drift, every, muscle,...
# 29982    [give, second, write, pain, pages, head, full,...
# Name: llr, Length: 16764, dtype: object

# %%
df2 = pd.DataFrame(columns=('lr','w'))

# %%
df2
# Out:
# Empty DataFrame
# Columns: [lr, w]
# Index: []
